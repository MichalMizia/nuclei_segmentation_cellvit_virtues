# %% [markdown]
# # Part 3 - Masked Attention & Boundary Attention Results
#
# This notebook loads and visualizes the results from training the CellVit decoder with:
# - **Masked Attention**: Attention mechanism that focuses on relevant regions
# - **Boundary Attention**: Special attention for cell boundaries
#
# The model was trained using the `Part3_maked_att_boundary.py` script.
#
# ## Results Overview
#
# This notebook will display:
# 1. Training and validation loss curves
# 2. Validation Dice score progression
# 3. Visual comparison of predictions vs ground truth on test samples

# %%
import sys
import os
import warnings
warnings.filterwarnings("ignore", message=".*weights_only=False.*") # ignore warning from torch for loading models
os.environ["RAY_OBJECT_STORE_ALLOW_SLOW_STORAGE"] = "1" 
# 1. Get the path to the directory above the current one (i.e., the project root)
# os.getcwd() gives '.../project_root/notebook'
# '..' steps up to '.../project_root'
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.insert(0, project_root)
    
from config import *
print(project_root)

import torch
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import pickle as pkl
from omegaconf import OmegaConf
from einops import rearrange
from tqdm import tqdm
import importlib
# Out:
# /data/code/jon/project-2-gradient_tri_scent

# %%
# project imports
from src.dataset.datasets.mm_base import build_mm_datasets, MultimodalDataset
from src.dataset.datasets.embeddings_dataset import EmbeddingsDataset # precomputed embeddings ds
from src.utils.plot_utils import visualize_multichannel_image
from src.modules.flex_dual_virtues.flex_dual_virtues_new_init import build_flex_dual_virtues_encoder
from src.utils.marker_utils import load_marker_embeddings
from src.utils.utils import load_checkpoint_safetensors
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /data/code/jon/project-2-gradient_tri_scent/src/modules/flex_dual_virtues/flex_dual_virtues_new_init.py:9
#       8 import xformers
# ----> 9 raise ImportError("xFormers disabled for debugging")
#      10 from src.modules.flex_dual_virtues.layers.transformer_xformers import MarkerAttentionEncoderBlock, ChannelAttentionEncoderBlock, FullAttentionEncoderBlock, PatchAttentionBlock
#
# ImportError: xFormers disabled for debugging
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 5
#       3 from src.dataset.datasets.embeddings_dataset import EmbeddingsDataset # precomputed embeddings ds
#       4 from src.utils.plot_utils import visualize_multichannel_image
# ----> 5 from src.modules.flex_dual_virtues.flex_dual_virtues_new_init import build_flex_dual_virtues_encoder
#       6 from src.utils.marker_utils import load_marker_embeddings
#       7 from src.utils.utils import load_checkpoint_safetensors
#
# File /data/code/jon/project-2-gradient_tri_scent/src/modules/flex_dual_virtues/flex_dual_virtues_new_init.py:18
#      15         logger.info(f'Using xformers for FlexDualVirTues')
#      17 except ImportError:
# ---> 18     from src.modules.flex_dual_virtues.layers.transformers_flashattention import MarkerAttentionEncoderBlock, ChannelAttentionEncoderBlock, FullAttentionEncoderBlock, PatchAttentionBlock
#      19     from src.modules.flex_dual_virtues.layers.mask_utils_flashattention import build_selfattention_bias_channel_concat, build_selfattention_bias, SA_BIAS_CACHE
#      20     USE_XFORMERS = False
#
# File /data/code/jon/project-2-gradient_tri_scent/src/modules/flex_dual_virtues/layers/transformers_flashattention.py:6
#       4 from einops import rearrange
#       5 from loguru import logger
# ----> 6 from src.modules.flex_dual_virtues.layers.attention_flashattention import \
#       7     MHAwithPosEmb
#       8 from src.modules.flex_dual_virtues.layers.basics import build_feedforward
#       9 from src.modules.flex_dual_virtues.layers.mask_utils_flashattention import (
#      10     build_selfattention_bias, build_selfattention_bias_channel_concat,
#      11     cached_build_selfattention_bias,
#      12     cached_build_selfattention_bias_channel_concat,
#      13     cached_get_non_zero_indices)
#
# File /data/code/jon/project-2-gradient_tri_scent/src/modules/flex_dual_virtues/layers/attention_flashattention.py:4
#       2 import torch
#       3 import torch.nn as nn
# ----> 4 from flash_attn.flash_attn_interface import flash_attn_varlen_qkvpacked_func
#       5 from src.modules.flex_dual_virtues.layers.positional_embeddings import (
#       6     LearnablePositionalEmbedding2D, PositionalEmbedding2D,
#       7     RotaryPositionalEmbedding2D)
#       8 from torch.nn import functional as F
#
# File /opt/conda/envs/tissuevit/lib/python3.12/site-packages/flash_attn/__init__.py:3
#       1 __version__ = "2.8.3"
# ----> 3 from flash_attn.flash_attn_interface import (
#       4     flash_attn_func,
#       5     flash_attn_kvpacked_func,
#       6     flash_attn_qkvpacked_func,
#       7     flash_attn_varlen_func,
#       8     flash_attn_varlen_kvpacked_func,
#       9     flash_attn_varlen_qkvpacked_func,
#      10     flash_attn_with_kvcache,
#      11 )
#
# File /opt/conda/envs/tissuevit/lib/python3.12/site-packages/flash_attn/flash_attn_interface.py:15
#      13     from .flash_attn_triton_amd import interface_fa as flash_attn_gpu
#      14 else:
# ---> 15     import flash_attn_2_cuda as flash_attn_gpu
#      17 # isort: on
#      19 def maybe_contiguous(x):
#
# ImportError: /opt/conda/envs/tissuevit/lib/python3.12/site-packages/flash_attn_2_cuda.cpython-312-x86_64-linux-gnu.so: undefined symbol: _ZN3c105ErrorC2ENS_14SourceLocationENSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE

# %%
from src.models.cellvit_decoder import CellViTDecoder
import src.utils.metrics as m
importlib.reload(m)
from src.utils.metrics import CombinedLoss, calculate_dice_score, calculate_f1_score, calculate_panoptic_quality, calculate_iou_score
from src.models.utils.train_loop import train_loop

num_classes = 10
checkpoint_dir = "./checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)
device = "cuda"

# %%
base_cfg = OmegaConf.load("../src/dataset/configs/base_config.yaml")
base_cfg.marker_embedding_dir = "../src/dataset/esm2_t30_150M_UR50D"
marker_embeddings = load_marker_embeddings(base_cfg.marker_embedding_dir)
orion_subset_cfg = OmegaConf.load("../src/dataset/configs/orion_subset.yaml")
ds_cfg = OmegaConf.merge(base_cfg, orion_subset_cfg)

# %%
ds = build_mm_datasets(ds_cfg)
# Out:
# 2025-12-16 15:12:57.093 | DEBUG    | src.dataset.datasets.mm_base:__init__:44 - Loading dataset orion from /data/virtues_orion_dataset/virtues_example/orion_subset
# 2025-12-16 15:12:57.120 | INFO     | src.dataset.datasets.multiplex_base:__init__:30 - Multiplex Normalization metadata: QuantileMultiplexNormalizeMetadata(normalizer_name='q_99', rnd_crop_folder_name='random_crops_256_no_log', channel_file_name='channels', mean_name='mean', std_name='std', quantile_path='quantiles/q99.csv')
# 2025-12-16 15:12:57.446 | INFO     | src.dataset.datasets.multiplex_base:__init__:40 - Crop folder /data/virtues_orion_dataset/virtues_example/orion_subset/cycif/random_crops_256_no_log exists
# /data/code/jon/project-2-gradient_tri_scent/src/dataset/datasets/multiplex_base.py:59: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.channels_per_image.fillna(1, inplace=True)
# /data/code/jon/project-2-gradient_tri_scent/src/dataset/datasets/multiplex_base.py:61: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.channels_per_image = self.channels_per_image.replace(1, True)
# 2025-12-16 15:12:57.479 | INFO     | src.dataset.datasets.multiplex_base:__init__:93 - Quantile:                   Hoechst  AF1   CD31    CD45   CD68  Argo550    CD4  FOXP3  \
# orion_aijcgfvk_0      NaN  NaN  486.0  2245.0  538.0      NaN  371.0  236.0
# orion_aisfibhi_0      NaN  NaN  393.0  1603.0  513.0      NaN  424.0  238.0
# orion_bzoahikx_0      NaN  NaN  440.0  2892.0  936.0      NaN  550.0  266.0
# orion_cnrgtuax_0      NaN  NaN  365.0  1122.0  799.0      NaN  415.0  257.0
# orion_cqxbwsky_0      NaN  NaN  641.0  3067.0  923.0      NaN  745.0  330.0
#
#                    CD8a  CD45RO   CD20  PD-L1    CD3e  CD163  E-cadherin  \
# orion_aijcgfvk_0  279.0  1116.0  275.0  565.0   560.0  972.0      2214.0
# orion_aisfibhi_0  278.0   611.0  270.0  547.0   607.0  678.0      1086.0
# orion_bzoahikx_0  726.0  1113.0  496.0  968.0  1167.0  886.0       914.0
# orion_cnrgtuax_0  335.0   752.0  350.0  649.0   567.0  487.0      1393.0
# orion_cqxbwsky_0  386.0   748.0  474.0  624.0  1193.0  939.0      2979.0
#
#                    PD-1    Ki67  Pan-CK    SMA
# orion_aijcgfvk_0  436.0  2733.0  1602.0  622.0
# orion_aisfibhi_0  437.0   874.0  2629.0  806.0
# orion_bzoahikx_0  470.0   569.0  2180.0  628.0
# orion_cnrgtuax_0  313.0   562.0  1899.0  905.0
# orion_cqxbwsky_0  593.0  1430.0  2298.0  912.0
# 2025-12-16 15:12:57.484 | WARNING  | src.dataset.datasets.multiplex_base:__init__:164 - Could not find embedding for Hoechst with Exclude
# 2025-12-16 15:12:57.485 | WARNING  | src.dataset.datasets.multiplex_base:__init__:164 - Could not find embedding for AF1 with Exclude
# 2025-12-16 15:12:57.486 | WARNING  | src.dataset.datasets.multiplex_base:__init__:164 - Could not find embedding for Argo550 with Exclude
# 2025-12-16 15:12:57.487 | INFO     | src.dataset.datasets.multiplex_base:__init__:169 - Found embeddings for 16 markers. Embeddings for 3 markers not found.
# 2025-12-16 15:12:57.488 | INFO     | src.dataset.datasets.multiplex_base:__init__:175 - Apply median filter: False
# 2025-12-16 15:12:57.489 | INFO     | src.dataset.datasets.multiplex_base:__init__:178 - Apply gaussian filter: False
# 2025-12-16 15:12:57.492 | INFO     | src.dataset.datasets.he_base:__init__:26 - H&E Normalization metadata: BaseHENormalizeMetadata(rnd_crop_folder_name='random_crops_256')

# %% [markdown]
# ## Visualize 1 multichannel image

# %%
uniprot_to_name = ds[0].unimodal_datasets["cycif"].get_marker_embedding_index_to_name_dict()

tissue_ids = ds[0].unimodal_datasets["cycif"].get_tissue_ids()
train_len = int(0.8 * len(tissue_ids))
train_tids = tissue_ids[:train_len]
test_tids = tissue_ids[train_len:]

channels = np.array(ds[0].unimodal_datasets["cycif"].get_marker_embedding_indices(tissue_ids[0]))
tissue = np.array(ds[0].unimodal_datasets["cycif"].get_tissue(tissue_ids[0]))

print(f"Tissue shape: {tissue.shape}")
print(f"SP: {list(map(lambda x: uniprot_to_name[x], channels))}")

#visualize_multichannel_image(tissue)
#plt.show()
# Out:
# Tissue shape: (16, 3000, 3000)
# SP: ['CD31', 'CD45', 'CD68', 'CD4', 'FOXP3', 'CD8a', 'CD45RO', 'CD20', 'PD-L1', 'CD3e', 'CD163', 'E-cadherin', 'PD-1', 'Ki67', 'Pan-CK', 'SMA']

# %%
# class weights for later use
from src.models.utils.class_weights import compute_class_weights

train_class_weights = compute_class_weights(train_tids, ds[0], 10)
print(train_class_weights)
# Out:
# tensor([ 1.0000,  6.3123, 20.0000, 11.1076,  6.5096, 20.0000, 20.0000, 20.0000,
#         20.0000, 20.0000])

# %%
# mx_tok_config = OmegaConf.load("channel_attn_tok.yaml")

with open(VIRTUES_WEIGHTS_PATH + "/config.pkl", "rb") as f:
    virtues_cfg = pkl.load(f)

encoder = build_flex_dual_virtues_encoder(virtues_cfg, marker_embeddings)
encoder.cuda()

weights = load_checkpoint_safetensors(VIRTUES_WEIGHTS_PATH + "/checkpoints/checkpoint-94575/model.safetensors")
# rename weights
weights_encoder = {}
for k, v in weights.items():
    if k.startswith("encoder."):
        weights_encoder[k[len("encoder."):]] = v

encoder.load_state_dict(weights_encoder, strict=False)
# Out:
# 2025-12-16 15:13:13.452 | INFO     | src.modules.flex_dual_virtues.flex_dual_virtues_new_init:__init__:128 - Using protein embedding: esm with shape torch.Size([213, 640])
# 2025-12-16 15:13:13.460 | INFO     | src.modules.flex_dual_virtues.flex_dual_virtues_new_init:__init__:147 - Using protein fusion type: add
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['encoder.0.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.0.encoder_layer.multi_head_attention.pos_emb.rope1d.sin', 'encoder.2.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.2.encoder_layer.multi_head_attention.pos_emb.rope1d.sin', 'encoder.4.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.4.encoder_layer.multi_head_attention.pos_emb.rope1d.sin', 'encoder.6.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.6.encoder_layer.multi_head_attention.pos_emb.rope1d.sin', 'encoder.8.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.8.encoder_layer.multi_head_attention.pos_emb.rope1d.sin', 'encoder.10.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.10.encoder_layer.multi_head_attention.pos_emb.rope1d.sin', 'encoder.12.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.12.encoder_layer.multi_head_attention.pos_emb.rope1d.sin', 'encoder.14.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.14.encoder_layer.multi_head_attention.pos_emb.rope1d.sin'])

# %%
from src.models.wrappers.virtues_wrapper import VirtuesWrapper
wrapper = VirtuesWrapper(encoder=encoder, device="cuda", autocast_dtype=torch.float16)

# %% [markdown]
# ## Load Pre-computed Embeddings
#
# Loading VirTues embeddings that were pre-computed for efficient training.

# %%
from_scratch=False
path = os.path.join("/data", "embeddings", "virtues_sp_only")
if from_scratch:
    # SP Only, include_he_data=False by default
    wrapper.process_dataset(ds[0], return_intermediates=True, intermediate_layers=[4,8,12])
    wrapper.save_embeddings(path)
else:
    wrapper.load_embeddings(path)
# Out:
# 100%|██████████| 35/35 [02:22<00:00,  4.08s/it]

# %%
print("OK")
# Out:
# OK

# %%
for key, emb in wrapper.embeddings.items():
    print(key, emb["pss"].shape, emb["intermediate_pss"][0].shape, len(emb["intermediate_pss"]))
    break
# Out:
# orion_aijcgfvk_0 torch.Size([140625, 512]) torch.Size([140625, 512]) 3

# %%
all_items = [(tid, emb["pss"], emb["intermediate_pss"]) for tid, emb in wrapper.embeddings.items()]
n = len(all_items)
train_items = all_items[: int(0.8 * n)]
test_items  = all_items[int(0.8 * n):]

# 25x25 batches from 375x375 => each is 15x15 patches => 120x120 px (120=15xpatch_size)
train_ds = EmbeddingsDataset(train_items, ds=ds[0], batches_from_item=25)
test_ds  = EmbeddingsDataset(test_items, ds=ds[0], batches_from_item=25)

def collate_batch(batch):
    _, he_img, mask, pss, intermediate_pss = zip(*batch)
    inter = [torch.stack([it[i] for it in intermediate_pss]) for i in range(len(intermediate_pss[0]))]
    return torch.stack(pss), torch.stack(mask), torch.stack(he_img), inter  # pss: (B, h, w, D), mask: (B, H, W)

train_loader = DataLoader(train_ds, batch_size=128, shuffle=True, num_workers=0, collate_fn=collate_batch, pin_memory=True)
test_loader  = DataLoader(test_ds, batch_size=128, shuffle=False, num_workers=0, collate_fn=collate_batch, pin_memory=True)
# Out:
# Preloading masks: 100%|██████████| 28/28 [00:00<00:00, 29.84it/s]
# Preloading H&E images: 100%|██████████| 28/28 [00:16<00:00,  1.70it/s]
# Preloading CyCIF images: 100%|██████████| 28/28 [01:28<00:00,  3.17s/it]
# Processing items: 0it [00:00, ?it/s]

# %%
from src.models.cellvit_decoder import CellViTDecoder
from src.models.utils.train_loop import train_loop

# %% [markdown]
# ## Load Saved Training Results
#
# Now we load the training metrics and trained model from the checkpoint directory.

# %%
# Load saved training metrics
path = os.path.join(checkpoint_dir, "training_metrics_part3_masked_att.npz")

data = np.load(path)

train_losses = data["train_losses"]
val_losses   = data["val_losses"]
val_dices    = data["val_dices"]

print(f"Loaded metrics from: {path}")
print(f"Number of epochs: {len(train_losses)}")
print(f"Best validation Dice: {np.max(val_dices):.4f} at epoch {np.argmax(val_dices)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 path = os.path.join(checkpoint_dir, "training_metrics_global_context.npz")
#       3 data = np.load(path)
#       5 train_losses = data["train_losses"]
#
# NameError: name 'checkpoint_dir' is not defined

# %%
# Load trained model
decoder = CellViTDecoder(
    embed_dim=512,
    num_nuclei_classes=10,
    drop_rate=0.3,
    original_channels=19,  # he + sp image
    patch_dropout_rate=0.0,
    boundary_attention=True,
    use_masked_attention=True,
)
decoder.to(device)

model_path = os.path.join(checkpoint_dir, "best_cellvit_masked_att.pth")
decoder.load_state_dict(torch.load(model_path))
decoder.eval()

print(f"Loaded model from: {model_path}")

# %%
## Training Metrics Visualization
plt.figure(figsize=(15, 5))

# Loss curves
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss', linewidth=2)
plt.plot(val_losses, label='Val Loss', linewidth=2)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.title('Loss Curves - Masked Attention & Boundary Attention', fontsize=14, fontweight='bold')
plt.legend(fontsize=11)
plt.grid(True, alpha=0.3)

# Dice score curve
plt.subplot(1, 2, 2)
plt.plot(val_dices, label='Val Dice Score', color='orange', linewidth=2)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Dice Score', fontsize=12)
best_dice = np.max(val_dices)
best_epoch = np.argmax(val_dices)
plt.title(f'Validation Dice Score\nBest: {best_dice:.4f} @ Epoch {best_epoch}', fontsize=14, fontweight='bold')
plt.legend(fontsize=11)
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\n{'='*60}")
print(f"Training Summary:")
print(f"{'='*60}")
print(f"Total Epochs: {len(train_losses)}")
print(f"Final Train Loss: {train_losses[-1]:.4f}")
print(f"Final Val Loss: {val_losses[-1]:.4f}")
print(f"Best Validation Dice: {best_dice:.4f} (Epoch {best_epoch})")
print(f"Final Validation Dice: {val_dices[-1]:.4f}")
print(f"{'='*60}")

# %% [markdown]
# ## Visualize example outputs from the decoder
#
# Here we created an additional dataset from test_items, with the only difference being batches_from_item is set to 5 instead of 25. This causes each patch to be larger and enables us to see more.

# %%
decoder.eval()

vis_ds = EmbeddingsDataset(test_items, ds=ds[0], batches_from_item=5)

show_images = 4
dataset_len = len(vis_ds)
indices = [int((dataset_len / show_images) * i) for i in range(show_images)]

with torch.no_grad():
    for row, idx in enumerate(indices):
        fig, axes = plt.subplots(1, 3, figsize=(12, 5))

        tid, img, mask, pss, intermediate_pss = vis_ds[idx]

        pss = pss.unsqueeze(0).to(device)
        mask = mask.unsqueeze(0).to(device).long()
        img = img.unsqueeze(0).to(device)
        intermediate_pss = [ip.unsqueeze(0).to(device) for ip in intermediate_pss]

        input = [img] + intermediate_pss + [pss]

        outputs = decoder(input)
        pred_logits = outputs["nuclei_type_map"]
        pred_mask = torch.argmax(pred_logits, dim=1)

        dice = calculate_dice_score(pred_mask, mask, num_classes)

        # Load full HE image for visualization
        he_img = ds[0].unimodal_datasets["he"]._get_tissue_all_channels(tid)
        he_vis = (
            he_img.transpose(1, 2, 0)
            if he_img.shape[0] == 3
            else he_img[0]
        )

        axes[0].imshow(he_vis)
        axes[0].set_title("H&E")
        axes[0].axis("off")

        axes[1].imshow(
            mask[0].cpu().numpy(),
            cmap="tab20",
            vmin=0,
            vmax=num_classes - 1,
        )
        axes[1].set_title("Ground Truth")
        axes[1].axis("off")

        axes[2].imshow(
            pred_mask[0].cpu().numpy(),
            cmap="tab20",
            vmin=0,
            vmax=num_classes - 1,
        )
        axes[2].set_title(f"Prediction (Dice: {dice:.3f})")
        axes[2].axis("off")

        del pss, mask, img, intermediate_pss, input, outputs, pred_logits, pred_mask
        torch.cuda.empty_cache()

        plt.tight_layout()
        plt.show()
# Out:
# Preloading masks: 100%|██████████| 7/7 [00:02<00:00,  2.40it/s]
# Preloading H&E images: 100%|██████████| 7/7 [00:11<00:00,  1.62s/it]
# Preloading CyCIF images:  29%|██▊       | 2/7 [00:24<01:01, 12.24s/it]
