# %% [markdown]
# # Part 2 - Training a CellVit nuclei_type_map decoder along with the virtues encoder
#
# ![image.png](attachment:05bbf855-9c06-45e6-bfd6-a120678331dd.png)
#
# We adapt the CellVit decoder by removing one upsampling layer from each `red` block and removing the cyan upsampling layer from the bottom. This is done because VirTues uses 8px patch size and CellVit uses 16px which causes the default decoder to upsample 16x. To not lose network complexity each upsampling (ConvTranspose2D layer) is replaced by a 1x1 Convolution layer.
#
# For loss, we have used a weighted sum of `cross-entropy` on pixel-level reconstruction, `dice loss` and `focal-tversky loss` for class imbalance. Similar to CellVit paper.
#
# We also updated the provided file `/src/modules/virtues/flex_dual_virtues/flex_dual_virtues_new_init.py` to enable the extraction of intermediate transformer features for skip connections in the decoder.
#
# **Step 1 - Training decoder on precomputed embeddings from VirTues (SP only or SP + H&E embeddings)**
#
# This method saves a lot of computational time by not recomputing embeddings for each forward pass, however it strips the possibility of using augmentations on H&E images, which is one of the most useful methods of reducing overfitting. We concluded 4 experiments in this stage:
#
# - SP Only, no class weights, no skip connections (pss token replicated for all steps)
# - SP Only, class weights, skip connections with intermediate features, stochastic patch drop
# - SP + H&E, class weights, skip connections, stochastic patch drop
#
# **Step 2 - Single run on the best previous method with additional augmentations**

# %%
import sys
import os
import warnings
warnings.filterwarnings("ignore", message=".*weights_only=False.*") # ignore warning from torch for loading models
os.environ["RAY_OBJECT_STORE_ALLOW_SLOW_STORAGE"] = "1" 
# 1. Get the path to the directory above the current one (i.e., the project root)
# os.getcwd() gives '.../project_root/notebook'
# '..' steps up to '.../project_root'
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.insert(0, project_root)
    
from config import *
print(project_root)

import torch
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import pickle as pkl
from omegaconf import OmegaConf
from einops import rearrange
from tqdm import tqdm
import importlib
# Out:
# /home/mizia/project-2-gradient_tri_scent

# %%
# project imports
from src.dataset.datasets.mm_base import build_mm_datasets, MultimodalDataset
from src.dataset.datasets.embeddings_dataset import EmbeddingsDataset # precomputed embeddings ds
from src.utils.plot_utils import visualize_multichannel_image
from src.modules.flex_dual_virtues.flex_dual_virtues_new_init import build_flex_dual_virtues_encoder
from src.utils.marker_utils import load_marker_embeddings
from src.utils.utils import load_checkpoint_safetensors
# Out:
# 2025-12-10 19:14:42.385 | INFO     | src.modules.flex_dual_virtues.flex_dual_virtues_new_init:<module>:23 - Using flash attention for FlexDualVirTues

# %%
from src.models.cellvit_decoder import CellViTDecoder
import src.utils.metrics as m
importlib.reload(m)
from src.utils.metrics import CombinedLoss, calculate_dice_score, calculate_f1_score, calculate_panoptic_quality, calculate_iou_score
from src.models.utils.train_loop import train_loop

num_classes = 10
checkpoint_dir = "./checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)
device = "cuda"

# %%
base_cfg = OmegaConf.load("../src/dataset/configs/base_config.yaml")
base_cfg.marker_embedding_dir = "../src/dataset/esm2_t30_150M_UR50D"
marker_embeddings = load_marker_embeddings(base_cfg.marker_embedding_dir)
orion_subset_cfg = OmegaConf.load("../src/dataset/configs/orion_subset.yaml")
ds_cfg = OmegaConf.merge(base_cfg, orion_subset_cfg)

# %%
ds = build_mm_datasets(ds_cfg)
# Out:
# 2025-12-10 19:14:42.987 | DEBUG    | src.dataset.datasets.mm_base:__init__:44 - Loading dataset orion from /data/virtues_orion_dataset/virtues_example/orion_subset
# 2025-12-10 19:14:42.999 | INFO     | src.dataset.datasets.multiplex_base:__init__:30 - Multiplex Normalization metadata: QuantileMultiplexNormalizeMetadata(normalizer_name='q_99', rnd_crop_folder_name='random_crops_256_no_log', channel_file_name='channels', mean_name='mean', std_name='std', quantile_path='quantiles/q99.csv')
# 2025-12-10 19:14:43.377 | INFO     | src.dataset.datasets.multiplex_base:__init__:40 - Crop folder /data/virtues_orion_dataset/virtues_example/orion_subset/cycif/random_crops_256_no_log exists
# /home/mizia/project-2-gradient_tri_scent/src/dataset/datasets/multiplex_base.py:59: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.channels_per_image.fillna(1, inplace=True)
# /home/mizia/project-2-gradient_tri_scent/src/dataset/datasets/multiplex_base.py:61: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.channels_per_image = self.channels_per_image.replace(1, True)
# 2025-12-10 19:14:43.402 | INFO     | src.dataset.datasets.multiplex_base:__init__:93 - Quantile:                   Hoechst  AF1   CD31    CD45   CD68  Argo550    CD4  FOXP3  \
# orion_aijcgfvk_0      NaN  NaN  486.0  2245.0  538.0      NaN  371.0  236.0
# orion_aisfibhi_0      NaN  NaN  393.0  1603.0  513.0      NaN  424.0  238.0
# orion_bzoahikx_0      NaN  NaN  440.0  2892.0  936.0      NaN  550.0  266.0
# orion_cnrgtuax_0      NaN  NaN  365.0  1122.0  799.0      NaN  415.0  257.0
# orion_cqxbwsky_0      NaN  NaN  641.0  3067.0  923.0      NaN  745.0  330.0
#
#                    CD8a  CD45RO   CD20  PD-L1    CD3e  CD163  E-cadherin  \
# orion_aijcgfvk_0  279.0  1116.0  275.0  565.0   560.0  972.0      2214.0
# orion_aisfibhi_0  278.0   611.0  270.0  547.0   607.0  678.0      1086.0
# orion_bzoahikx_0  726.0  1113.0  496.0  968.0  1167.0  886.0       914.0
# orion_cnrgtuax_0  335.0   752.0  350.0  649.0   567.0  487.0      1393.0
# orion_cqxbwsky_0  386.0   748.0  474.0  624.0  1193.0  939.0      2979.0
#
#                    PD-1    Ki67  Pan-CK    SMA
# orion_aijcgfvk_0  436.0  2733.0  1602.0  622.0
# orion_aisfibhi_0  437.0   874.0  2629.0  806.0
# orion_bzoahikx_0  470.0   569.0  2180.0  628.0
# orion_cnrgtuax_0  313.0   562.0  1899.0  905.0
# orion_cqxbwsky_0  593.0  1430.0  2298.0  912.0
# 2025-12-10 19:14:43.406 | WARNING  | src.dataset.datasets.multiplex_base:__init__:164 - Could not find embedding for Hoechst with Exclude
# 2025-12-10 19:14:43.407 | WARNING  | src.dataset.datasets.multiplex_base:__init__:164 - Could not find embedding for AF1 with Exclude
# 2025-12-10 19:14:43.407 | WARNING  | src.dataset.datasets.multiplex_base:__init__:164 - Could not find embedding for Argo550 with Exclude
# 2025-12-10 19:14:43.408 | INFO     | src.dataset.datasets.multiplex_base:__init__:169 - Found embeddings for 16 markers. Embeddings for 3 markers not found.
# 2025-12-10 19:14:43.409 | INFO     | src.dataset.datasets.multiplex_base:__init__:175 - Apply median filter: False
# 2025-12-10 19:14:43.409 | INFO     | src.dataset.datasets.multiplex_base:__init__:178 - Apply gaussian filter: False
# 2025-12-10 19:14:43.411 | INFO     | src.dataset.datasets.he_base:__init__:26 - H&E Normalization metadata: BaseHENormalizeMetadata(rnd_crop_folder_name='random_crops_256')

# %% [markdown]
# ## Visualize 1 multichannel image

# %%
uniprot_to_name = ds[0].unimodal_datasets["cycif"].get_marker_embedding_index_to_name_dict()

tissue_ids = ds[0].unimodal_datasets["cycif"].get_tissue_ids()
train_len = int(0.8 * len(tissue_ids))
train_tids = tissue_ids[:train_len]
test_tids = tissue_ids[train_len:]

channels = np.array(ds[0].unimodal_datasets["cycif"].get_marker_embedding_indices(tissue_ids[0]))
tissue = np.array(ds[0].unimodal_datasets["cycif"].get_tissue(tissue_ids[0]))

print(f"Tissue shape: {tissue.shape}")
print(f"SP: {list(map(lambda x: uniprot_to_name[x], channels))}")

# visualize_multichannel_image(tissue)
# plt.show()
# Out:
# Tissue shape: (16, 3000, 3000)
# SP: ['CD31', 'CD45', 'CD68', 'CD4', 'FOXP3', 'CD8a', 'CD45RO', 'CD20', 'PD-L1', 'CD3e', 'CD163', 'E-cadherin', 'PD-1', 'Ki67', 'Pan-CK', 'SMA']

# %%
# class weights for later use
from src.models.utils.class_weights import compute_class_weights

train_class_weights = compute_class_weights(train_tids, ds[0], 10)
print(train_class_weights)
# Out:
# tensor([ 1.0000,  6.3123, 20.0000, 11.1076,  6.5096, 20.0000, 20.0000, 20.0000,
#         20.0000, 20.0000])

# %%
# mx_tok_config = OmegaConf.load("channel_attn_tok.yaml")

with open(VIRTUES_WEIGHTS_PATH + "/config.pkl", "rb") as f:
    virtues_cfg = pkl.load(f)

encoder = build_flex_dual_virtues_encoder(virtues_cfg, marker_embeddings)
encoder.cuda()

weights = load_checkpoint_safetensors(VIRTUES_WEIGHTS_PATH + "/checkpoints/checkpoint-94575/model.safetensors")
# rename weights
weights_encoder = {}
for k, v in weights.items():
    if k.startswith("encoder."):
        weights_encoder[k[len("encoder."):]] = v

encoder.load_state_dict(weights_encoder, strict=False)
# Out:
# 2025-12-10 19:14:51.304 | INFO     | src.modules.flex_dual_virtues.flex_dual_virtues_new_init:__init__:128 - Using protein embedding: esm with shape torch.Size([213, 640])
# 2025-12-10 19:14:51.306 | INFO     | src.modules.flex_dual_virtues.flex_dual_virtues_new_init:__init__:147 - Using protein fusion type: add
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['encoder.0.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.0.encoder_layer.multi_head_attention.pos_emb.rope1d.sin', 'encoder.2.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.2.encoder_layer.multi_head_attention.pos_emb.rope1d.sin', 'encoder.4.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.4.encoder_layer.multi_head_attention.pos_emb.rope1d.sin', 'encoder.6.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.6.encoder_layer.multi_head_attention.pos_emb.rope1d.sin', 'encoder.8.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.8.encoder_layer.multi_head_attention.pos_emb.rope1d.sin', 'encoder.10.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.10.encoder_layer.multi_head_attention.pos_emb.rope1d.sin', 'encoder.12.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.12.encoder_layer.multi_head_attention.pos_emb.rope1d.sin', 'encoder.14.encoder_layer.multi_head_attention.pos_emb.rope1d.cos', 'encoder.14.encoder_layer.multi_head_attention.pos_emb.rope1d.sin'])

# %%
from src.models.wrappers.virtues_wrapper import VirtuesWrapper
wrapper = VirtuesWrapper(encoder=encoder, device="cuda", autocast_dtype=torch.float16)

# %% [markdown]
# ## Custom `return_intermediates` flag
#
# We have added a custom `return_intermediates` boolean flag to the virtues encoder in file `src/modules/flex_dual_virtues/flex_dual_virtues_new_init.py`.
# This flag is used to return all the intermediate representations between the transformer layers. Using the default config, there are 16 intermediate representations. This flag can be passed to method forward_list of encoder, which causes it to return a third item in the tuple which is the representations list of length 16. Each item is a list of size N where N is the list size passed to forward list. Each item in that nested list is the same shape as a PSS token.
#
# The `VirtuesWrapper` class processes the entire dataset, and for every tissue_id, it saves a file under path. In that file there is a dict with 2 keys which can be loaded with pytorch. These keys are `intermediate_pss` and `pss`.

# %%
from_scratch=False
path = os.path.join("/data", "embeddings", "virtues_sp_only")
if from_scratch:
    # SP Only, include_he_data=False by default
    wrapper.process_dataset(ds[0], return_intermediates=True, intermediate_layers=[4,8,12])
    wrapper.save_embeddings(path)
else:
    wrapper.load_embeddings(path)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 35/35 [02:07<00:00,  3.65s/it]

# %%
for key, emb in wrapper.embeddings.items():
    print(key, emb["pss"].shape, emb["intermediate_pss"][0].shape, len(emb["intermediate_pss"]))
    break
# Out:
# orion_aijcgfvk_0 torch.Size([140625, 512]) torch.Size([140625, 512]) 3

# %%
all_items = [(tid, emb["pss"], emb["intermediate_pss"]) for tid, emb in wrapper.embeddings.items()]
n = len(all_items)
train_items = all_items[: int(0.8 * n)]
test_items  = all_items[int(0.8 * n):]

# 25x25 batches from 375x375 => each is 15x15 patches => 120x120 px (120=15xpatch_size)
train_ds = EmbeddingsDataset(train_items, ds=ds[0], batches_from_item=25)
test_ds  = EmbeddingsDataset(test_items, ds=ds[0], batches_from_item=25)

def collate_batch(batch):
    _, he_img, mask, pss, intermediate_pss = zip(*batch)
    inter = [torch.stack([it[i] for it in intermediate_pss]) for i in range(len(intermediate_pss[0]))]
    return torch.stack(pss), torch.stack(mask), torch.stack(he_img), inter  # pss: (B, h, w, D), mask: (B, H, W)

train_loader = DataLoader(train_ds, batch_size=128, shuffle=True, num_workers=0, collate_fn=collate_batch, pin_memory=True)
test_loader  = DataLoader(test_ds, batch_size=128, shuffle=False, num_workers=0, collate_fn=collate_batch, pin_memory=True)
# Out:
# Preloading masks: 100%|█████████████████████████████████████████████████████████████████████████| 28/28 [00:01<00:00, 21.47it/s]
# Preloading H&E images: 100%|████████████████████████████████████████████████████████████████████| 28/28 [00:18<00:00,  1.52it/s]
# Preloading CyCIF images: 100%|██████████████████████████████████████████████████████████████████| 28/28 [01:34<00:00,  3.36s/it]
# Processing items: 28it [00:12,  2.18it/s]
# Preloading masks: 100%|███████████████████████████████████████████████████████████████████████████| 7/7 [00:01<00:00,  6.97it/s]
# Preloading H&E images: 100%|██████████████████████████████████████████████████████████████████████| 7/7 [00:04<00:00,  1.74it/s]
# Preloading CyCIF images: 100%|████████████████████████████████████████████████████████████████████| 7/7 [00:18<00:00,  2.64s/it]
# Processing items: 7it [00:02,  2.36it/s]

# %% [markdown]
# ## 1. Training the CellVitDecoder on VirTues embeddings - only Spatial-Proteomics data
#
# Our first experiment is training a custom CellVitDecoder (8x instead of 16x upsampling) for precomputed embeddings using only SP data. Here, we simulate the original skip connections from CellVit using the final encoder embeddings for each connection, instead of the features from different encoder depths.

# %%
decoder = CellViTDecoder(
    embed_dim=512,  
    num_nuclei_classes=num_classes,
    drop_rate=0.3,
    original_channels=19,
    patch_dropout_rate=0.0
)
decoder.to(device)

optimizer = optim.AdamW(decoder.parameters(), lr=5e-4, weight_decay=1e-2)
criterion = CombinedLoss(num_classes=num_classes) # CE + Dice + Focal-Tversky
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=20, eta_min=1e-6)

# %%
decoder, train_losses, val_losses, val_dices = train_loop(
    train_loader,
    test_loader,
    decoder,
    criterion,
    optimizer,
    scheduler,
    num_epochs=100,
    early_stopping_patience=30,
    num_classes=10,
    device="cuda",
    save_path=os.path.join(checkpoint_dir, "best_cellvit_sp_only_skip.pth"),
    include_skip_connections=True, # copy pss for each connection
)
# Out:
# Epoch 1/100 | LR: 5.0e-04 | Train Loss: 0.9253 | Val Loss: 0.7305 | Val Dice: 0.4462
#   -->  New Best Dice: 0.4462 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 2/100 | LR: 4.9e-04 | Train Loss: 0.6796 | Val Loss: 0.6662 | Val Dice: 0.4848
#   -->  New Best Dice: 0.4848 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 3/100 | LR: 4.7e-04 | Train Loss: 0.6307 | Val Loss: 0.6214 | Val Dice: 0.5209
#   -->  New Best Dice: 0.5209 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 4/100 | LR: 4.5e-04 | Train Loss: 0.6099 | Val Loss: 0.6236 | Val Dice: 0.5365
#   -->  New Best Dice: 0.5365 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 5/100 | LR: 4.3e-04 | Train Loss: 0.5956 | Val Loss: 0.6046 | Val Dice: 0.5649
#   -->  New Best Dice: 0.5649 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 6/100 | LR: 4.0e-04 | Train Loss: 0.5851 | Val Loss: 0.5988 | Val Dice: 0.5732
#   -->  New Best Dice: 0.5732 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 7/100 | LR: 3.6e-04 | Train Loss: 0.5767 | Val Loss: 0.5913 | Val Dice: 0.5958
#   -->  New Best Dice: 0.5958 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 8/100 | LR: 3.3e-04 | Train Loss: 0.5706 | Val Loss: 0.5895 | Val Dice: 0.5836
# Epoch 9/100 | LR: 2.9e-04 | Train Loss: 0.5663 | Val Loss: 0.5871 | Val Dice: 0.5839
# Epoch 10/100 | LR: 2.5e-04 | Train Loss: 0.5631 | Val Loss: 0.5850 | Val Dice: 0.5928
# Epoch 11/100 | LR: 2.1e-04 | Train Loss: 0.5584 | Val Loss: 0.5802 | Val Dice: 0.5989
#   -->  New Best Dice: 0.5989 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 12/100 | LR: 1.7e-04 | Train Loss: 0.5549 | Val Loss: 0.5845 | Val Dice: 0.5971
# Epoch 13/100 | LR: 1.4e-04 | Train Loss: 0.5516 | Val Loss: 0.5798 | Val Dice: 0.6009
#   -->  New Best Dice: 0.6009 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 14/100 | LR: 1.0e-04 | Train Loss: 0.5488 | Val Loss: 0.5757 | Val Dice: 0.6029
#   -->  New Best Dice: 0.6029 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 15/100 | LR: 7.4e-05 | Train Loss: 0.5462 | Val Loss: 0.5803 | Val Dice: 0.6038
#   -->  New Best Dice: 0.6038 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 16/100 | LR: 4.9e-05 | Train Loss: 0.5441 | Val Loss: 0.5771 | Val Dice: 0.6066
#   -->  New Best Dice: 0.6066 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 17/100 | LR: 2.8e-05 | Train Loss: 0.5423 | Val Loss: 0.5786 | Val Dice: 0.6033
# Epoch 18/100 | LR: 1.3e-05 | Train Loss: 0.5409 | Val Loss: 0.5759 | Val Dice: 0.6063
# Epoch 19/100 | LR: 4.1e-06 | Train Loss: 0.5399 | Val Loss: 0.5747 | Val Dice: 0.6065
# Epoch 20/100 | LR: 5.0e-04 | Train Loss: 0.5394 | Val Loss: 0.5759 | Val Dice: 0.6058
# Epoch 21/100 | LR: 5.0e-04 | Train Loss: 0.5539 | Val Loss: 0.5950 | Val Dice: 0.5912
# Epoch 22/100 | LR: 4.9e-04 | Train Loss: 0.5502 | Val Loss: 0.5807 | Val Dice: 0.6045
# Epoch 23/100 | LR: 4.7e-04 | Train Loss: 0.5460 | Val Loss: 0.5790 | Val Dice: 0.6051
# Epoch 24/100 | LR: 4.5e-04 | Train Loss: 0.5425 | Val Loss: 0.5817 | Val Dice: 0.6021
# Epoch 25/100 | LR: 4.3e-04 | Train Loss: 0.5412 | Val Loss: 0.5788 | Val Dice: 0.6065
# Epoch 26/100 | LR: 4.0e-04 | Train Loss: 0.5368 | Val Loss: 0.5707 | Val Dice: 0.6139
#   -->  New Best Dice: 0.6139 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 27/100 | LR: 3.6e-04 | Train Loss: 0.5351 | Val Loss: 0.5795 | Val Dice: 0.6062
# Epoch 28/100 | LR: 3.3e-04 | Train Loss: 0.5332 | Val Loss: 0.5727 | Val Dice: 0.6122
# Epoch 29/100 | LR: 2.9e-04 | Train Loss: 0.5290 | Val Loss: 0.5678 | Val Dice: 0.6153
#   -->  New Best Dice: 0.6153 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 30/100 | LR: 2.5e-04 | Train Loss: 0.5262 | Val Loss: 0.5852 | Val Dice: 0.6052
# Epoch 31/100 | LR: 2.1e-04 | Train Loss: 0.5240 | Val Loss: 0.5768 | Val Dice: 0.6153
#   -->  New Best Dice: 0.6153 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 32/100 | LR: 1.7e-04 | Train Loss: 0.5218 | Val Loss: 0.5668 | Val Dice: 0.6182
#   -->  New Best Dice: 0.6182 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 33/100 | LR: 1.4e-04 | Train Loss: 0.5180 | Val Loss: 0.5742 | Val Dice: 0.6122
# Epoch 34/100 | LR: 1.0e-04 | Train Loss: 0.5166 | Val Loss: 0.5719 | Val Dice: 0.6102
# Epoch 35/100 | LR: 7.4e-05 | Train Loss: 0.5142 | Val Loss: 0.5701 | Val Dice: 0.6149
# Epoch 36/100 | LR: 4.9e-05 | Train Loss: 0.5119 | Val Loss: 0.5706 | Val Dice: 0.6191
#   -->  New Best Dice: 0.6191 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 37/100 | LR: 2.8e-05 | Train Loss: 0.5106 | Val Loss: 0.5731 | Val Dice: 0.6166
# Epoch 38/100 | LR: 1.3e-05 | Train Loss: 0.5094 | Val Loss: 0.5719 | Val Dice: 0.6177
# Epoch 39/100 | LR: 4.1e-06 | Train Loss: 0.5086 | Val Loss: 0.5713 | Val Dice: 0.6215
#   -->  New Best Dice: 0.6215 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 40/100 | LR: 5.0e-04 | Train Loss: 0.5082 | Val Loss: 0.5701 | Val Dice: 0.6191
# Epoch 41/100 | LR: 5.0e-04 | Train Loss: 0.5248 | Val Loss: 0.5730 | Val Dice: 0.6157
# Epoch 42/100 | LR: 4.9e-04 | Train Loss: 0.5236 | Val Loss: 0.5688 | Val Dice: 0.6168
# Epoch 43/100 | LR: 4.7e-04 | Train Loss: 0.5222 | Val Loss: 0.5762 | Val Dice: 0.6058
# Epoch 44/100 | LR: 4.5e-04 | Train Loss: 0.5185 | Val Loss: 0.5763 | Val Dice: 0.6060
# Epoch 45/100 | LR: 4.3e-04 | Train Loss: 0.5166 | Val Loss: 0.5708 | Val Dice: 0.6069
# Epoch 46/100 | LR: 4.0e-04 | Train Loss: 0.5133 | Val Loss: 0.5873 | Val Dice: 0.6076
# Epoch 47/100 | LR: 3.6e-04 | Train Loss: 0.5126 | Val Loss: 0.5683 | Val Dice: 0.6242
#   -->  New Best Dice: 0.6242 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 48/100 | LR: 3.3e-04 | Train Loss: 0.5086 | Val Loss: 0.5676 | Val Dice: 0.6227
# Epoch 49/100 | LR: 2.9e-04 | Train Loss: 0.5071 | Val Loss: 0.5710 | Val Dice: 0.6217
# Epoch 50/100 | LR: 2.5e-04 | Train Loss: 0.5043 | Val Loss: 0.5781 | Val Dice: 0.6118
# Epoch 51/100 | LR: 2.1e-04 | Train Loss: 0.5021 | Val Loss: 0.5805 | Val Dice: 0.6098
# Epoch 52/100 | LR: 1.7e-04 | Train Loss: 0.4999 | Val Loss: 0.5748 | Val Dice: 0.6227
# Epoch 53/100 | LR: 1.4e-04 | Train Loss: 0.4979 | Val Loss: 0.5827 | Val Dice: 0.6087
# Epoch 54/100 | LR: 1.0e-04 | Train Loss: 0.4950 | Val Loss: 0.5730 | Val Dice: 0.6192
# Epoch 55/100 | LR: 7.4e-05 | Train Loss: 0.4934 | Val Loss: 0.5722 | Val Dice: 0.6233
# Epoch 56/100 | LR: 4.9e-05 | Train Loss: 0.4918 | Val Loss: 0.5735 | Val Dice: 0.6226
# Epoch 57/100 | LR: 2.8e-05 | Train Loss: 0.4905 | Val Loss: 0.5738 | Val Dice: 0.6206
# Epoch 58/100 | LR: 1.3e-05 | Train Loss: 0.4897 | Val Loss: 0.5744 | Val Dice: 0.6210
# Epoch 59/100 | LR: 4.1e-06 | Train Loss: 0.4890 | Val Loss: 0.5749 | Val Dice: 0.6204
# Epoch 60/100 | LR: 5.0e-04 | Train Loss: 0.4886 | Val Loss: 0.5742 | Val Dice: 0.6210
# Epoch 61/100 | LR: 5.0e-04 | Train Loss: 0.5055 | Val Loss: 0.5742 | Val Dice: 0.6108
# Epoch 62/100 | LR: 4.9e-04 | Train Loss: 0.5053 | Val Loss: 0.5771 | Val Dice: 0.6130
# Epoch 63/100 | LR: 4.7e-04 | Train Loss: 0.5056 | Val Loss: 0.5823 | Val Dice: 0.6043
# Epoch 64/100 | LR: 4.5e-04 | Train Loss: 0.5016 | Val Loss: 0.5846 | Val Dice: 0.6117
# Epoch 65/100 | LR: 4.3e-04 | Train Loss: 0.5003 | Val Loss: 0.5853 | Val Dice: 0.6093
# Epoch 66/100 | LR: 4.0e-04 | Train Loss: 0.4974 | Val Loss: 0.5831 | Val Dice: 0.6094
# Epoch 67/100 | LR: 3.6e-04 | Train Loss: 0.4954 | Val Loss: 0.5703 | Val Dice: 0.6217
# Epoch 68/100 | LR: 3.3e-04 | Train Loss: 0.4941 | Val Loss: 0.5733 | Val Dice: 0.6179
# Epoch 69/100 | LR: 2.9e-04 | Train Loss: 0.4904 | Val Loss: 0.5729 | Val Dice: 0.6234
# Epoch 70/100 | LR: 2.5e-04 | Train Loss: 0.4890 | Val Loss: 0.5828 | Val Dice: 0.6192
# Epoch 71/100 | LR: 2.1e-04 | Train Loss: 0.4866 | Val Loss: 0.5739 | Val Dice: 0.6270
#   -->  New Best Dice: 0.6270 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 72/100 | LR: 1.7e-04 | Train Loss: 0.4848 | Val Loss: 0.5711 | Val Dice: 0.6286
#   -->  New Best Dice: 0.6286 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 73/100 | LR: 1.4e-04 | Train Loss: 0.4827 | Val Loss: 0.5755 | Val Dice: 0.6214
# Epoch 74/100 | LR: 1.0e-04 | Train Loss: 0.4806 | Val Loss: 0.5766 | Val Dice: 0.6256
# Epoch 75/100 | LR: 7.4e-05 | Train Loss: 0.4794 | Val Loss: 0.5788 | Val Dice: 0.6264
# Epoch 76/100 | LR: 4.9e-05 | Train Loss: 0.4778 | Val Loss: 0.5774 | Val Dice: 0.6247
# Epoch 77/100 | LR: 2.8e-05 | Train Loss: 0.4769 | Val Loss: 0.5791 | Val Dice: 0.6233
# Epoch 78/100 | LR: 1.3e-05 | Train Loss: 0.4758 | Val Loss: 0.5797 | Val Dice: 0.6228
# Epoch 79/100 | LR: 4.1e-06 | Train Loss: 0.4754 | Val Loss: 0.5793 | Val Dice: 0.6264
# Epoch 80/100 | LR: 5.0e-04 | Train Loss: 0.4750 | Val Loss: 0.5785 | Val Dice: 0.6246
# Epoch 81/100 | LR: 5.0e-04 | Train Loss: 0.4917 | Val Loss: 0.6096 | Val Dice: 0.5911
# Epoch 82/100 | LR: 4.9e-04 | Train Loss: 0.4935 | Val Loss: 0.5894 | Val Dice: 0.6235
# Epoch 83/100 | LR: 4.7e-04 | Train Loss: 0.4899 | Val Loss: 0.5746 | Val Dice: 0.6144
# Epoch 84/100 | LR: 4.5e-04 | Train Loss: 0.4899 | Val Loss: 0.5764 | Val Dice: 0.6188
# Epoch 85/100 | LR: 4.3e-04 | Train Loss: 0.4874 | Val Loss: 0.5785 | Val Dice: 0.6267
# Epoch 86/100 | LR: 4.0e-04 | Train Loss: 0.4849 | Val Loss: 0.5979 | Val Dice: 0.6043
# Epoch 87/100 | LR: 3.6e-04 | Train Loss: 0.4830 | Val Loss: 0.5740 | Val Dice: 0.6284
# Epoch 88/100 | LR: 3.3e-04 | Train Loss: 0.4813 | Val Loss: 0.5756 | Val Dice: 0.6236
# Epoch 89/100 | LR: 2.9e-04 | Train Loss: 0.4792 | Val Loss: 0.5790 | Val Dice: 0.6293
#   -->  New Best Dice: 0.6293 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 90/100 | LR: 2.5e-04 | Train Loss: 0.4773 | Val Loss: 0.5977 | Val Dice: 0.6135
# Epoch 91/100 | LR: 2.1e-04 | Train Loss: 0.4752 | Val Loss: 0.5801 | Val Dice: 0.6228
# Epoch 92/100 | LR: 1.7e-04 | Train Loss: 0.4738 | Val Loss: 0.5844 | Val Dice: 0.6203
# Epoch 93/100 | LR: 1.4e-04 | Train Loss: 0.4718 | Val Loss: 0.5799 | Val Dice: 0.6228
# Epoch 94/100 | LR: 1.0e-04 | Train Loss: 0.4701 | Val Loss: 0.5816 | Val Dice: 0.6237
# Epoch 95/100 | LR: 7.4e-05 | Train Loss: 0.4685 | Val Loss: 0.5921 | Val Dice: 0.6151
# Epoch 96/100 | LR: 4.9e-05 | Train Loss: 0.4675 | Val Loss: 0.5806 | Val Dice: 0.6246
# Epoch 97/100 | LR: 2.8e-05 | Train Loss: 0.4663 | Val Loss: 0.5852 | Val Dice: 0.6220
# Epoch 98/100 | LR: 1.3e-05 | Train Loss: 0.4658 | Val Loss: 0.5838 | Val Dice: 0.6241
# Epoch 99/100 | LR: 4.1e-06 | Train Loss: 0.4651 | Val Loss: 0.5849 | Val Dice: 0.6233
# Epoch 100/100 | LR: 5.0e-04 | Train Loss: 0.4651 | Val Loss: 0.5838 | Val Dice: 0.6240

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.title('Loss Curves')
plt.legend()
plt.grid(True)
plt.subplot(1, 2, 2)
plt.plot(val_dices, label='Val Dice Score', color='orange')
plt.title(f'Validation Dice Score (Best: {np.max(val_dices):.4f})')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2. Training the CellVitDecoder on VirTues embeddings - only Spatial-Proteomics data with Skip Connections
#
# In the second experiment, we rerun the first one but with actual skip connections from different layers of the encoder as well as the original image with 19 channels, (16 from SP and 3 from HE)

# %%
def collate_batch(batch):
    _, img, mask, pss, intermediate_pss = zip(*batch)
    inter = [torch.stack([it[i] for it in intermediate_pss]) for i in range(len(intermediate_pss[0]))]
    return torch.stack(pss), torch.stack(mask), torch.stack(img), inter  # pss: (B, h, w, D), mask: (B, H, W)

train_loader = DataLoader(train_ds, batch_size=4, shuffle=True, num_workers=0, collate_fn=collate_batch)
test_loader  = DataLoader(test_ds, batch_size=4, shuffle=False, num_workers=0, collate_fn=collate_batch)

decoder = CellViTDecoder(
    embed_dim=512,  
    num_nuclei_classes=10,
    drop_rate=0.3,
    original_channels=19, # he image (3) + SP (16)
    patch_dropout_rate=0.0
)
decoder.to(device)

optimizer = optim.AdamW(decoder.parameters(), lr=5e-4, weight_decay=1e-3)
# criterion = CombinedLoss(num_classes=num_classes, class_weights=train_class_weights.to(device)) # CE + Dice + Focal-Tversky
criterion = CombinedLoss(num_classes=num_classes) # CE + Dice + Focal-Tversky
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=20, eta_min=1e-6)

# %%
decoder, train_losses, val_losses, val_dices = train_loop(
    train_loader,
    test_loader,
    decoder,
    criterion,
    optimizer,
    scheduler,
    num_epochs=100,
    early_stopping_patience=30,
    num_classes=10,
    device="cuda",
    save_path=os.path.join(checkpoint_dir, "best_cellvit_sp_only_skip.pth"),
    include_skip_connections=True,
)
# Out:
# Epoch 1/75 [Train]: 100%|█████████████████████████████████████████████████████████████████| 175/175 [01:27<00:00,  2.00it/s]
# Epoch 1/75 | LR: 4.5e-04 | Train Loss: 0.9731 | Val Loss: 0.8628 | Val Dice: 0.2564
#   -->  New Best Dice: 0.2564 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 2/75 [Train]: 100%|█████████████████████████████████████████████████████████████████| 175/175 [01:24<00:00,  2.06it/s]
# Epoch 2/75 | LR: 3.3e-04 | Train Loss: 0.7219 | Val Loss: 0.7624 | Val Dice: 0.3311
#   -->  New Best Dice: 0.3311 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 3/75 [Train]: 100%|█████████████████████████████████████████████████████████████████| 175/175 [01:25<00:00,  2.05it/s]
# Epoch 3/75 | LR: 1.7e-04 | Train Loss: 0.6657 | Val Loss: 0.7207 | Val Dice: 0.3966
#   -->  New Best Dice: 0.3966 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 4/75 [Train]: 100%|█████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.02it/s]
# Epoch 4/75 | LR: 4.9e-05 | Train Loss: 0.6358 | Val Loss: 0.7325 | Val Dice: 0.3807
# Epoch 5/75 [Train]: 100%|█████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.02it/s]
# Epoch 5/75 | LR: 5.0e-04 | Train Loss: 0.6229 | Val Loss: 0.7102 | Val Dice: 0.3879
# Epoch 6/75 [Train]: 100%|█████████████████████████████████████████████████████████████████| 175/175 [01:25<00:00,  2.06it/s]
# Epoch 6/75 | LR: 4.9e-04 | Train Loss: 0.6203 | Val Loss: 0.7244 | Val Dice: 0.4268
#   -->  New Best Dice: 0.4268 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 7/75 [Train]: 100%|█████████████████████████████████████████████████████████████████| 175/175 [01:27<00:00,  2.00it/s]
# Epoch 7/75 | LR: 4.5e-04 | Train Loss: 0.5913 | Val Loss: 0.6930 | Val Dice: 0.4526
#   -->  New Best Dice: 0.4526 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 8/75 [Train]: 100%|█████████████████████████████████████████████████████████████████| 175/175 [01:27<00:00,  2.01it/s]
# Epoch 8/75 | LR: 4.0e-04 | Train Loss: 0.5711 | Val Loss: 0.7015 | Val Dice: 0.4814
#   -->  New Best Dice: 0.4814 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 9/75 [Train]: 100%|█████████████████████████████████████████████████████████████████| 175/175 [01:27<00:00,  2.00it/s]
# Epoch 9/75 | LR: 3.3e-04 | Train Loss: 0.5541 | Val Loss: 0.6906 | Val Dice: 0.4824
#   -->  New Best Dice: 0.4824 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 10/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.03it/s]
# Epoch 10/75 | LR: 2.5e-04 | Train Loss: 0.5438 | Val Loss: 0.6829 | Val Dice: 0.5059
#   -->  New Best Dice: 0.5059 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 11/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:25<00:00,  2.04it/s]
# Epoch 11/75 | LR: 1.7e-04 | Train Loss: 0.5339 | Val Loss: 0.6790 | Val Dice: 0.5068
#   -->  New Best Dice: 0.5068 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 12/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.01it/s]
# Epoch 12/75 | LR: 1.0e-04 | Train Loss: 0.5272 | Val Loss: 0.6752 | Val Dice: 0.5058
# Epoch 13/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:25<00:00,  2.04it/s]
# Epoch 13/75 | LR: 4.9e-05 | Train Loss: 0.5194 | Val Loss: 0.6696 | Val Dice: 0.5181
#   -->  New Best Dice: 0.5181 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 14/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:27<00:00,  2.01it/s]
# Epoch 14/75 | LR: 1.3e-05 | Train Loss: 0.5152 | Val Loss: 0.6721 | Val Dice: 0.5180
# Epoch 15/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:27<00:00,  2.00it/s]
# Epoch 15/75 | LR: 5.0e-04 | Train Loss: 0.5133 | Val Loss: 0.6640 | Val Dice: 0.5240
#   -->  New Best Dice: 0.5240 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 16/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.02it/s]
# Epoch 16/75 | LR: 5.0e-04 | Train Loss: 0.5320 | Val Loss: 0.7031 | Val Dice: 0.4995
# Epoch 17/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.02it/s]
# Epoch 17/75 | LR: 4.9e-04 | Train Loss: 0.5262 | Val Loss: 0.6730 | Val Dice: 0.5265
#   -->  New Best Dice: 0.5265 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 18/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.03it/s]
# Epoch 18/75 | LR: 4.7e-04 | Train Loss: 0.5125 | Val Loss: 0.6740 | Val Dice: 0.5231
# Epoch 19/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.03it/s]
# Epoch 19/75 | LR: 4.5e-04 | Train Loss: 0.5078 | Val Loss: 0.6716 | Val Dice: 0.5213
# Epoch 20/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.02it/s]
# Epoch 20/75 | LR: 4.3e-04 | Train Loss: 0.4993 | Val Loss: 0.6867 | Val Dice: 0.5165
# Epoch 21/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:25<00:00,  2.04it/s]
# Epoch 21/75 | LR: 4.0e-04 | Train Loss: 0.4973 | Val Loss: 0.6627 | Val Dice: 0.5341
#   -->  New Best Dice: 0.5341 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 22/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:27<00:00,  2.01it/s]
# Epoch 22/75 | LR: 3.6e-04 | Train Loss: 0.4968 | Val Loss: 0.6848 | Val Dice: 0.5192
# Epoch 23/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:25<00:00,  2.05it/s]
# Epoch 23/75 | LR: 3.3e-04 | Train Loss: 0.4905 | Val Loss: 0.6756 | Val Dice: 0.5301
# Epoch 24/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.02it/s]
# Epoch 24/75 | LR: 2.9e-04 | Train Loss: 0.4848 | Val Loss: 0.6867 | Val Dice: 0.5313
# Epoch 25/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.02it/s]
# Epoch 25/75 | LR: 2.5e-04 | Train Loss: 0.4798 | Val Loss: 0.6784 | Val Dice: 0.5379
#   -->  New Best Dice: 0.5379 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 26/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.02it/s]
# Epoch 26/75 | LR: 2.1e-04 | Train Loss: 0.4800 | Val Loss: 0.6985 | Val Dice: 0.5251
# Epoch 27/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:27<00:00,  2.01it/s]
# Epoch 27/75 | LR: 1.7e-04 | Train Loss: 0.4767 | Val Loss: 0.6597 | Val Dice: 0.5450
#   -->  New Best Dice: 0.5450 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 28/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:27<00:00,  2.01it/s]
# Epoch 28/75 | LR: 1.4e-04 | Train Loss: 0.4693 | Val Loss: 0.6703 | Val Dice: 0.5382
# Epoch 29/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.02it/s]
# Epoch 29/75 | LR: 1.0e-04 | Train Loss: 0.4672 | Val Loss: 0.6649 | Val Dice: 0.5409
# Epoch 30/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:27<00:00,  2.01it/s]
# Epoch 30/75 | LR: 7.4e-05 | Train Loss: 0.4645 | Val Loss: 0.6662 | Val Dice: 0.5461
#   -->  New Best Dice: 0.5461 (Saved to ./checkpoints/best_cellvit_sp_only_skip.pth)
# Epoch 31/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.01it/s]
# Epoch 31/75 | LR: 4.9e-05 | Train Loss: 0.4649 | Val Loss: 0.6697 | Val Dice: 0.5430
# Epoch 32/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:25<00:00,  2.04it/s]
# Epoch 32/75 | LR: 2.8e-05 | Train Loss: 0.4601 | Val Loss: 0.6681 | Val Dice: 0.5426
# Epoch 33/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:27<00:00,  2.01it/s]
# Epoch 33/75 | LR: 1.3e-05 | Train Loss: 0.4588 | Val Loss: 0.6668 | Val Dice: 0.5449
# Epoch 34/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.02it/s]
# Epoch 34/75 | LR: 4.1e-06 | Train Loss: 0.4597 | Val Loss: 0.6696 | Val Dice: 0.5433
# Epoch 35/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.03it/s]
# Epoch 35/75 | LR: 5.0e-04 | Train Loss: 0.4582 | Val Loss: 0.6754 | Val Dice: 0.5401
# Epoch 36/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:27<00:00,  2.01it/s]
# Epoch 36/75 | LR: 5.0e-04 | Train Loss: 0.4852 | Val Loss: 0.6886 | Val Dice: 0.5185
# Epoch 37/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:26<00:00,  2.02it/s]
# Epoch 37/75 | LR: 5.0e-04 | Train Loss: 0.4751 | Val Loss: 0.6763 | Val Dice: 0.5391
# Epoch 38/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:25<00:00,  2.04it/s]
# Epoch 38/75 | LR: 4.9e-04 | Train Loss: 0.4779 | Val Loss: 0.7064 | Val Dice: 0.5284
# Epoch 39/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:27<00:00,  2.00it/s]
# Epoch 39/75 | LR: 4.9e-04 | Train Loss: 0.4722 | Val Loss: 0.6987 | Val Dice: 0.5282
# Epoch 40/75 [Train]: 100%|████████████████████████████████████████████████████████████████| 175/175 [01:25<00:00,  2.05it/s]
# Epoch 40/75 | LR: 4.8e-04 | Train Loss: 0.4677 | Val Loss: 0.6966 | Val Dice: 0.5301
# Early stopping triggered after 10 epochs without improvement.

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.title('Loss Curves')
plt.legend()
plt.grid(True)
plt.subplot(1, 2, 2)
plt.plot(val_dices, label='Val Dice Score', color='orange')
plt.title(f'Validation Dice Score (Best: {np.max(val_dices):.4f})')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 3. Training the CellVitDecoder on VirTues embeddings - Spatial-Proteomics + H&E data + Skip Connections
#
# We use embeddings precomputed from SP + H&E data, with real skip connections but without a specific oversampling strategy or class weights for Cross-Entropy

# %%
from_scratch=False
path = os.path.join("/data", "embeddings", "virtues_sp_he")
if from_scratch:
    wrapper.process_dataset(ds[0], include_he_data=True, return_intermediates=True, intermediate_layers=[4,8,12])
    wrapper.save_embeddings(path)
else:
    wrapper.load_embeddings(path)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 35/35 [01:53<00:00,  3.23s/it]

# %%
for key, emb in wrapper.embeddings.items():
    print(key, emb["pss"].shape, emb["intermediate_pss"][0].shape, len(emb["intermediate_pss"]))
    break
# Out:
# orion_aijcgfvk_0 torch.Size([140625, 512]) torch.Size([140625, 512]) 3

# %%
all_items = [(tid, emb["pss"], emb["intermediate_pss"]) for tid, emb in wrapper.embeddings.items()]
n = len(all_items)
train_items = all_items[: int(0.8 * n)]
test_items  = all_items[int(0.8 * n):]

# 25x25 batches from 375x375 => each is 15x15 patches => 120x120 px (120=15xpatch_size)
train_ds = EmbeddingsDataset(train_items, ds=ds[0], batches_from_item=25)
test_ds  = EmbeddingsDataset(test_items, ds=ds[0], batches_from_item=25)

def collate_batch(batch):
    _, he_img, mask, pss, intermediate_pss = zip(*batch)
    inter = [torch.stack([it[i] for it in intermediate_pss]) for i in range(len(intermediate_pss[0]))]
    return torch.stack(pss), torch.stack(mask), torch.stack(he_img), inter  # pss: (B, h, w, D), mask: (B, H, W)

train_loader = DataLoader(train_ds, batch_size=128, shuffle=True, num_workers=0, collate_fn=collate_batch, pin_memory=True)
test_loader  = DataLoader(test_ds, batch_size=128, shuffle=False, num_workers=0, collate_fn=collate_batch, pin_memory=True)
# Out:
# Preloading masks: 100%|█████████████████████████████████████████████████████████████████████| 28/28 [00:00<00:00, 35.12it/s]
# Preloading H&E images: 100%|████████████████████████████████████████████████████████████████| 28/28 [00:11<00:00,  2.47it/s]
# Preloading CyCIF images: 100%|██████████████████████████████████████████████████████████████| 28/28 [01:00<00:00,  2.17s/it]
# Processing items: 28it [01:10,  2.53s/it]
# Preloading masks: 100%|███████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 86.33it/s]
# Preloading H&E images: 100%|██████████████████████████████████████████████████████████████████| 7/7 [00:02<00:00,  2.54it/s]
# Preloading CyCIF images: 100%|████████████████████████████████████████████████████████████████| 7/7 [00:14<00:00,  2.14s/it]
# Processing items: 7it [00:04,  1.72it/s]

# %%
decoder = CellViTDecoder(
    embed_dim=512,  
    num_nuclei_classes=10,
    drop_rate=0.3,
    original_channels=19, # he + sp image
    patch_dropout_rate=0.0
)
decoder.to(device)

optimizer = optim.AdamW(decoder.parameters(), lr=5e-4, weight_decay=1e-2)
criterion = CombinedLoss(num_classes=num_classes) # CE + Dice + Focal-Tversky
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=20, eta_min=1e-6)

# %%
decoder, train_losses, val_losses, val_dices = train_loop( # printing clears every 10 epochs to not freeze jupyter
    train_loader,
    test_loader,
    decoder,
    criterion,
    optimizer,
    scheduler,
    num_epochs=100,
    early_stopping_patience=30,
    num_classes=10,
    device="cuda",
    save_path=os.path.join(checkpoint_dir, "best_cellvit_sp_he_skip.pth"),
    include_skip_connections=True,
)
# Out:
# Epoch 1/100 | LR: 5.0e-04 | Train Loss: 0.9774 | Val Loss: 0.7862 | Val Dice: 0.4270
#   -->  New Best Dice: 0.4270 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 2/100 | LR: 4.9e-04 | Train Loss: 0.6939 | Val Loss: 0.6633 | Val Dice: 0.4762
#   -->  New Best Dice: 0.4762 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 3/100 | LR: 4.7e-04 | Train Loss: 0.6424 | Val Loss: 0.6599 | Val Dice: 0.4794
#   -->  New Best Dice: 0.4794 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 4/100 | LR: 4.5e-04 | Train Loss: 0.6179 | Val Loss: 0.6290 | Val Dice: 0.5432
#   -->  New Best Dice: 0.5432 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 5/100 | LR: 4.3e-04 | Train Loss: 0.6019 | Val Loss: 0.6265 | Val Dice: 0.5485
#   -->  New Best Dice: 0.5485 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 6/100 | LR: 4.0e-04 | Train Loss: 0.5913 | Val Loss: 0.6043 | Val Dice: 0.5856
#   -->  New Best Dice: 0.5856 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 7/100 | LR: 3.6e-04 | Train Loss: 0.5840 | Val Loss: 0.6133 | Val Dice: 0.5708
# Epoch 8/100 | LR: 3.3e-04 | Train Loss: 0.5783 | Val Loss: 0.5966 | Val Dice: 0.5786
# Epoch 9/100 | LR: 2.9e-04 | Train Loss: 0.5742 | Val Loss: 0.5939 | Val Dice: 0.5925
#   -->  New Best Dice: 0.5925 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 10/100 | LR: 2.5e-04 | Train Loss: 0.5694 | Val Loss: 0.5887 | Val Dice: 0.5978
#   -->  New Best Dice: 0.5978 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 11/100 | LR: 2.1e-04 | Train Loss: 0.5653 | Val Loss: 0.6060 | Val Dice: 0.5896
# Epoch 12/100 | LR: 1.7e-04 | Train Loss: 0.5622 | Val Loss: 0.5777 | Val Dice: 0.6042
#   -->  New Best Dice: 0.6042 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 13/100 | LR: 1.4e-04 | Train Loss: 0.5593 | Val Loss: 0.5824 | Val Dice: 0.6054
#   -->  New Best Dice: 0.6054 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 14/100 | LR: 1.0e-04 | Train Loss: 0.5557 | Val Loss: 0.5825 | Val Dice: 0.6008
# Epoch 15/100 | LR: 7.4e-05 | Train Loss: 0.5534 | Val Loss: 0.5810 | Val Dice: 0.6060
#   -->  New Best Dice: 0.6060 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 16/100 | LR: 4.9e-05 | Train Loss: 0.5511 | Val Loss: 0.5818 | Val Dice: 0.6048
# Epoch 17/100 | LR: 2.8e-05 | Train Loss: 0.5494 | Val Loss: 0.5784 | Val Dice: 0.6083
#   -->  New Best Dice: 0.6083 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 18/100 | LR: 1.3e-05 | Train Loss: 0.5476 | Val Loss: 0.5787 | Val Dice: 0.6081
# Epoch 19/100 | LR: 4.1e-06 | Train Loss: 0.5469 | Val Loss: 0.5790 | Val Dice: 0.6104
#   -->  New Best Dice: 0.6104 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 20/100 | LR: 5.0e-04 | Train Loss: 0.5465 | Val Loss: 0.5794 | Val Dice: 0.6076
# Epoch 21/100 | LR: 5.0e-04 | Train Loss: 0.5603 | Val Loss: 0.5923 | Val Dice: 0.5924
# Epoch 22/100 | LR: 4.9e-04 | Train Loss: 0.5561 | Val Loss: 0.5858 | Val Dice: 0.6047
# Epoch 23/100 | LR: 4.7e-04 | Train Loss: 0.5538 | Val Loss: 0.5884 | Val Dice: 0.5973
# Epoch 24/100 | LR: 4.5e-04 | Train Loss: 0.5498 | Val Loss: 0.5881 | Val Dice: 0.6058
# Epoch 25/100 | LR: 4.3e-04 | Train Loss: 0.5472 | Val Loss: 0.5925 | Val Dice: 0.5867
# Epoch 26/100 | LR: 4.0e-04 | Train Loss: 0.5451 | Val Loss: 0.5854 | Val Dice: 0.6087
# Epoch 27/100 | LR: 3.6e-04 | Train Loss: 0.5416 | Val Loss: 0.5929 | Val Dice: 0.6024
# Epoch 28/100 | LR: 3.3e-04 | Train Loss: 0.5388 | Val Loss: 0.5785 | Val Dice: 0.5997
# Epoch 29/100 | LR: 2.9e-04 | Train Loss: 0.5364 | Val Loss: 0.5837 | Val Dice: 0.6078
# Epoch 30/100 | LR: 2.5e-04 | Train Loss: 0.5326 | Val Loss: 0.5765 | Val Dice: 0.6098
# Epoch 31/100 | LR: 2.1e-04 | Train Loss: 0.5299 | Val Loss: 0.5729 | Val Dice: 0.6192
#   -->  New Best Dice: 0.6192 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 32/100 | LR: 1.7e-04 | Train Loss: 0.5266 | Val Loss: 0.5718 | Val Dice: 0.6192
# Epoch 33/100 | LR: 1.4e-04 | Train Loss: 0.5246 | Val Loss: 0.5718 | Val Dice: 0.6174
# Epoch 34/100 | LR: 1.0e-04 | Train Loss: 0.5220 | Val Loss: 0.5736 | Val Dice: 0.6160
# Epoch 35/100 | LR: 7.4e-05 | Train Loss: 0.5198 | Val Loss: 0.5774 | Val Dice: 0.6192
# Epoch 36/100 | LR: 4.9e-05 | Train Loss: 0.5179 | Val Loss: 0.5762 | Val Dice: 0.6194
#   -->  New Best Dice: 0.6194 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 37/100 | LR: 2.8e-05 | Train Loss: 0.5165 | Val Loss: 0.5738 | Val Dice: 0.6208
#   -->  New Best Dice: 0.6208 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 38/100 | LR: 1.3e-05 | Train Loss: 0.5153 | Val Loss: 0.5742 | Val Dice: 0.6220
#   -->  New Best Dice: 0.6220 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 39/100 | LR: 4.1e-06 | Train Loss: 0.5144 | Val Loss: 0.5733 | Val Dice: 0.6233
#   -->  New Best Dice: 0.6233 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 40/100 | LR: 5.0e-04 | Train Loss: 0.5139 | Val Loss: 0.5729 | Val Dice: 0.6229
# Epoch 41/100 | LR: 5.0e-04 | Train Loss: 0.5298 | Val Loss: 0.5802 | Val Dice: 0.6135
# Epoch 42/100 | LR: 4.9e-04 | Train Loss: 0.5285 | Val Loss: 0.5867 | Val Dice: 0.6075
# Epoch 43/100 | LR: 4.7e-04 | Train Loss: 0.5263 | Val Loss: 0.5742 | Val Dice: 0.6102
# Epoch 44/100 | LR: 4.5e-04 | Train Loss: 0.5245 | Val Loss: 0.5789 | Val Dice: 0.6088
# Epoch 45/100 | LR: 4.3e-04 | Train Loss: 0.5221 | Val Loss: 0.5766 | Val Dice: 0.6137
# Epoch 46/100 | LR: 4.0e-04 | Train Loss: 0.5195 | Val Loss: 0.5711 | Val Dice: 0.6190
# Epoch 47/100 | LR: 3.6e-04 | Train Loss: 0.5168 | Val Loss: 0.5928 | Val Dice: 0.6032
# Epoch 48/100 | LR: 3.3e-04 | Train Loss: 0.5151 | Val Loss: 0.5746 | Val Dice: 0.6147
# Epoch 49/100 | LR: 2.9e-04 | Train Loss: 0.5125 | Val Loss: 0.5781 | Val Dice: 0.6158
# Epoch 50/100 | LR: 2.5e-04 | Train Loss: 0.5088 | Val Loss: 0.5732 | Val Dice: 0.6184
# Epoch 51/100 | LR: 2.1e-04 | Train Loss: 0.5070 | Val Loss: 0.5776 | Val Dice: 0.6138
# Epoch 52/100 | LR: 1.7e-04 | Train Loss: 0.5044 | Val Loss: 0.5749 | Val Dice: 0.6187
# Epoch 53/100 | LR: 1.4e-04 | Train Loss: 0.5027 | Val Loss: 0.5743 | Val Dice: 0.6252
#   -->  New Best Dice: 0.6252 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 54/100 | LR: 1.0e-04 | Train Loss: 0.5004 | Val Loss: 0.5741 | Val Dice: 0.6237
# Epoch 55/100 | LR: 7.4e-05 | Train Loss: 0.4987 | Val Loss: 0.5757 | Val Dice: 0.6245
# Epoch 56/100 | LR: 4.9e-05 | Train Loss: 0.4969 | Val Loss: 0.5758 | Val Dice: 0.6229
# Epoch 57/100 | LR: 2.8e-05 | Train Loss: 0.4957 | Val Loss: 0.5739 | Val Dice: 0.6243
# Epoch 58/100 | LR: 1.3e-05 | Train Loss: 0.4946 | Val Loss: 0.5758 | Val Dice: 0.6256
#   -->  New Best Dice: 0.6256 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 59/100 | LR: 4.1e-06 | Train Loss: 0.4940 | Val Loss: 0.5762 | Val Dice: 0.6228
# Epoch 60/100 | LR: 5.0e-04 | Train Loss: 0.4937 | Val Loss: 0.5757 | Val Dice: 0.6227
# Epoch 61/100 | LR: 5.0e-04 | Train Loss: 0.5101 | Val Loss: 0.5780 | Val Dice: 0.6061
# Epoch 62/100 | LR: 4.9e-04 | Train Loss: 0.5115 | Val Loss: 0.5873 | Val Dice: 0.6142
# Epoch 63/100 | LR: 4.7e-04 | Train Loss: 0.5087 | Val Loss: 0.5898 | Val Dice: 0.6147
# Epoch 64/100 | LR: 4.5e-04 | Train Loss: 0.5069 | Val Loss: 0.5907 | Val Dice: 0.6060
# Epoch 65/100 | LR: 4.3e-04 | Train Loss: 0.5050 | Val Loss: 0.5826 | Val Dice: 0.6126
# Epoch 66/100 | LR: 4.0e-04 | Train Loss: 0.5026 | Val Loss: 0.5801 | Val Dice: 0.6165
# Epoch 67/100 | LR: 3.6e-04 | Train Loss: 0.5000 | Val Loss: 0.5790 | Val Dice: 0.6141
# Epoch 68/100 | LR: 3.3e-04 | Train Loss: 0.4985 | Val Loss: 0.6149 | Val Dice: 0.5965
# Epoch 69/100 | LR: 2.9e-04 | Train Loss: 0.4957 | Val Loss: 0.5888 | Val Dice: 0.6144
# Epoch 70/100 | LR: 2.5e-04 | Train Loss: 0.4932 | Val Loss: 0.5809 | Val Dice: 0.6233
# Epoch 71/100 | LR: 2.1e-04 | Train Loss: 0.4914 | Val Loss: 0.5795 | Val Dice: 0.6269
#   -->  New Best Dice: 0.6269 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 72/100 | LR: 1.7e-04 | Train Loss: 0.4897 | Val Loss: 0.5773 | Val Dice: 0.6262
# Epoch 73/100 | LR: 1.4e-04 | Train Loss: 0.4873 | Val Loss: 0.5831 | Val Dice: 0.6220
# Epoch 74/100 | LR: 1.0e-04 | Train Loss: 0.4853 | Val Loss: 0.5782 | Val Dice: 0.6263
# Epoch 75/100 | LR: 7.4e-05 | Train Loss: 0.4841 | Val Loss: 0.5859 | Val Dice: 0.6212
# Epoch 76/100 | LR: 4.9e-05 | Train Loss: 0.4828 | Val Loss: 0.5798 | Val Dice: 0.6258
# Epoch 77/100 | LR: 2.8e-05 | Train Loss: 0.4819 | Val Loss: 0.5785 | Val Dice: 0.6277
#   -->  New Best Dice: 0.6277 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 78/100 | LR: 1.3e-05 | Train Loss: 0.4808 | Val Loss: 0.5809 | Val Dice: 0.6258
# Epoch 79/100 | LR: 4.1e-06 | Train Loss: 0.4804 | Val Loss: 0.5789 | Val Dice: 0.6281
#   -->  New Best Dice: 0.6281 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 80/100 | LR: 5.0e-04 | Train Loss: 0.4800 | Val Loss: 0.5796 | Val Dice: 0.6275
# Epoch 81/100 | LR: 5.0e-04 | Train Loss: 0.4963 | Val Loss: 0.5901 | Val Dice: 0.6105
# Epoch 82/100 | LR: 4.9e-04 | Train Loss: 0.4986 | Val Loss: 0.6038 | Val Dice: 0.6018
# Epoch 83/100 | LR: 4.7e-04 | Train Loss: 0.4965 | Val Loss: 0.5918 | Val Dice: 0.6109
# Epoch 84/100 | LR: 4.5e-04 | Train Loss: 0.4939 | Val Loss: 0.5812 | Val Dice: 0.6169
# Epoch 85/100 | LR: 4.3e-04 | Train Loss: 0.4922 | Val Loss: 0.5798 | Val Dice: 0.6194
# Epoch 86/100 | LR: 4.0e-04 | Train Loss: 0.4907 | Val Loss: 0.5811 | Val Dice: 0.6184
# Epoch 87/100 | LR: 3.6e-04 | Train Loss: 0.4887 | Val Loss: 0.5792 | Val Dice: 0.6136
# Epoch 88/100 | LR: 3.3e-04 | Train Loss: 0.4867 | Val Loss: 0.5885 | Val Dice: 0.6169
# Epoch 89/100 | LR: 2.9e-04 | Train Loss: 0.4843 | Val Loss: 0.5791 | Val Dice: 0.6229
# Epoch 90/100 | LR: 2.5e-04 | Train Loss: 0.4827 | Val Loss: 0.5792 | Val Dice: 0.6213
# Epoch 91/100 | LR: 2.1e-04 | Train Loss: 0.4803 | Val Loss: 0.5923 | Val Dice: 0.6165
# Epoch 92/100 | LR: 1.7e-04 | Train Loss: 0.4783 | Val Loss: 0.5857 | Val Dice: 0.6260
# Epoch 93/100 | LR: 1.4e-04 | Train Loss: 0.4765 | Val Loss: 0.5865 | Val Dice: 0.6225
# Epoch 94/100 | LR: 1.0e-04 | Train Loss: 0.4748 | Val Loss: 0.5831 | Val Dice: 0.6239
# Epoch 95/100 | LR: 7.4e-05 | Train Loss: 0.4737 | Val Loss: 0.5826 | Val Dice: 0.6284
#   -->  New Best Dice: 0.6284 (Saved to ./checkpoints/best_cellvit_sp_he_skip.pth)
# Epoch 96/100 | LR: 4.9e-05 | Train Loss: 0.4724 | Val Loss: 0.5866 | Val Dice: 0.6273
# Epoch 97/100 | LR: 2.8e-05 | Train Loss: 0.4715 | Val Loss: 0.5840 | Val Dice: 0.6276
# Epoch 98/100 | LR: 1.3e-05 | Train Loss: 0.4708 | Val Loss: 0.5845 | Val Dice: 0.6279
# Epoch 99/100 | LR: 4.1e-06 | Train Loss: 0.4702 | Val Loss: 0.5860 | Val Dice: 0.6267
# Epoch 100/100 | LR: 5.0e-04 | Train Loss: 0.4701 | Val Loss: 0.5847 | Val Dice: 0.6266

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.title('Loss Curves')
plt.legend()
plt.grid(True)
plt.subplot(1, 2, 2)
plt.plot(val_dices, label='Val Dice Score', color='orange')
plt.title(f'Validation Dice Score (Best: {np.max(val_dices):.4f})')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Visualize example outputs from the decoder
#
# Here we created an additional dataset from test_items, with the only difference being batches_from_item is set to 5 instead of 25. This causes each patch to be larger and enables us to see more.

# %%
decoder.eval()

# vis_ds  = EmbeddingsDataset(test_items, ds=ds[0], batches_from_item=5)

show_images = 4
dataset_len = len(vis_ds)
indices = [int((dataset_len / show_images) * i) for i in range(show_images)]

with torch.no_grad():
    for row, idx in enumerate(indices):
        fig, axes = plt.subplots(1, 3, figsize=(12, 16))

        tid, img, mask, pss, intermediate_pss = vis_ds[idx]
        
        pss = pss.unsqueeze(0).to(device)
        mask = mask.unsqueeze(0).to(device).long()
        img = img.unsqueeze(0).to(device)
        intermediate_pss = [ip.unsqueeze(0).to(device) for ip in intermediate_pss]
        
        input = [img] + intermediate_pss + [pss]
        
        outputs = decoder(input)
        pred_logits = outputs['nuclei_type_map']
        pred_mask = torch.argmax(pred_logits, dim=1)

        dice = calculate_dice_score(pred_mask, mask, num_classes)
        
        he_img = ds[0].unimodal_datasets["he"]._get_tissue_all_channels(tid)
        he_vis = he_img.transpose(1, 2, 0) if he_img.shape[0] == 3 else he_img[0]
        
        axes[0].imshow(he_vis)
        axes[0].set_title(f"Sample {row + 1}: HE")
        axes[0].axis('off')
        
        axes[1].imshow(mask[0].cpu().numpy(), cmap='tab20', vmin=0, vmax=num_classes-1)
        axes[1].set_title(f"Ground Truth")
        axes[1].axis('off')
        
        axes[2].imshow(pred_mask[0].cpu().numpy(), cmap='tab20', vmin=0, vmax=num_classes-1)
        axes[2].set_title(f"Prediction Dice: {dice:.3f} PQ: {pq:.3f} IOU: {iou:.3f}")
        axes[2].axis('off')
        
        # Clean up
        del pss, mask, img, intermediate_pss, input, outputs, pred_logits, pred_mask
        torch.cuda.empty_cache()

        plt.tight_layout()
        plt.show()
