# %% [markdown]
# ## Preparing equal data split for 4 experiments

# %%
import sys
import os
import warnings
warnings.filterwarnings("ignore", message=".*weights_only=False.*") # ignore warning from torch for loading models
os.environ["RAY_OBJECT_STORE_ALLOW_SLOW_STORAGE"] = "1" 
# 1. Get the path to the directory above the current one (i.e., the project root)
# os.getcwd() gives '.../project_root/notebook'
# '..' steps up to '.../project_root'
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.insert(0, project_root)
    
from config import *
print(project_root)

import torch
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import pickle as pkl
from omegaconf import OmegaConf
from einops import rearrange
from tqdm import tqdm
import importlib
import random

from src.dataset.datasets.mm_base import build_mm_datasets
# Out:
# /data/code/jon/project-2-gradient_tri_scent

# %%
SEED = 42
TEST_FRAC = 0.2  # 80/20
OUT_NAME = f"two_folds_seed{SEED}_tissue_split.pkl"


def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)

# %%
def make_two_folds(tissue_ids, seed=42, test_frac=0.2):
    """
    Make 2 deterministic folds (tissue-level), both using ~ (1-test_frac) train.
    Fold2 test set is a rotated chunk so it is different from fold1.
    """
    tissue_ids = list(tissue_ids)
    rnd = random.Random(seed)
    rnd.shuffle(tissue_ids)

    n = len(tissue_ids)
    n_test = max(1, int(round(test_frac * n)))
    n_train = n - n_test

    # Fold 1: last chunk is test
    fold1_train = tissue_ids[:n_train]
    fold1_test = tissue_ids[n_train:]

    # Fold 2: rotate by test chunk size so test chunk changes
    rotated = tissue_ids[n_test:] + tissue_ids[:n_test]
    fold2_train = rotated[:n_train]
    fold2_test = rotated[n_train:]

    folds = {
        "seed": seed,
        "test_frac": test_frac,
        "n_total": n,
        "fold1": {"train": fold1_train, "test": fold1_test},
        "fold2": {"train": fold2_train, "test": fold2_test},
    }
    return folds

# %%
set_seed(SEED)

# ----------------------------
# Build dataset configs exactly like you do
# ----------------------------
base_cfg = OmegaConf.load("../src/dataset/configs/base_config.yaml")
base_cfg.marker_embedding_dir = "../src/dataset/esm2_t30_150M_UR50D"
marker_embeddings = load_marker_embeddings(base_cfg.marker_embedding_dir)
orion_subset_cfg = OmegaConf.load("../src/dataset/configs/orion_subset.yaml")
ds_cfg = OmegaConf.merge(base_cfg, orion_subset_cfg)

ds = build_mm_datasets(ds_cfg)

tissue_ids = ds[0].unimodal_datasets["cycif"].get_tissue_ids()
print(f"Total tissues: {len(tissue_ids)}")

folds = make_two_folds(tissue_ids, seed=SEED, test_frac=TEST_FRAC)

# ----------------------------
# Sanity checks: no overlap
# ----------------------------
f1_tr = set(folds["fold1"]["train"])
f1_te = set(folds["fold1"]["test"])
f2_tr = set(folds["fold2"]["train"])
f2_te = set(folds["fold2"]["test"])

print("\nSanity checks:")
print("Fold1 sizes:", len(f1_tr), len(f1_te), "overlap:", len(f1_tr & f1_te))
print("Fold2 sizes:", len(f2_tr), len(f2_te), "overlap:", len(f2_tr & f2_te))

# optional: how different are the two test sets?
print("Fold1 test ∩ Fold2 test:", len(f1_te & f2_te))

# ----------------------------
# Save into checkpoints
# ----------------------------
checkpoint_dir = os.path.join(project_root, "notebooks", "checkpoints")
os.makedirs(checkpoint_dir, exist_ok=True)

out_path = os.path.join(checkpoint_dir, OUT_NAME)
with open(out_path, "wb") as f:
    pkl.dump(folds, f)

print(f"\nSaved folds to: {out_path}")
# Out:
# 2025-12-17 21:16:47.997 | DEBUG    | src.dataset.datasets.mm_base:__init__:44 - Loading dataset orion from /data/virtues_orion_dataset/virtues_example/orion_subset
# 2025-12-17 21:16:48.001 | INFO     | src.dataset.datasets.multiplex_base:__init__:30 - Multiplex Normalization metadata: QuantileMultiplexNormalizeMetadata(normalizer_name='q_99', rnd_crop_folder_name='random_crops_256_no_log', channel_file_name='channels', mean_name='mean', std_name='std', quantile_path='quantiles/q99.csv')
# 2025-12-17 21:16:48.036 | INFO     | src.dataset.datasets.multiplex_base:__init__:40 - Crop folder /data/virtues_orion_dataset/virtues_example/orion_subset/cycif/random_crops_256_no_log exists
# /data/code/jon/project-2-gradient_tri_scent/src/dataset/datasets/multiplex_base.py:59: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.channels_per_image.fillna(1, inplace=True)
# /data/code/jon/project-2-gradient_tri_scent/src/dataset/datasets/multiplex_base.py:61: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.channels_per_image = self.channels_per_image.replace(1, True)
# 2025-12-17 21:16:48.053 | INFO     | src.dataset.datasets.multiplex_base:__init__:93 - Quantile:                   Hoechst  AF1   CD31    CD45   CD68  Argo550    CD4  FOXP3  \
# orion_aijcgfvk_0      NaN  NaN  486.0  2245.0  538.0      NaN  371.0  236.0
# orion_aisfibhi_0      NaN  NaN  393.0  1603.0  513.0      NaN  424.0  238.0
# orion_bzoahikx_0      NaN  NaN  440.0  2892.0  936.0      NaN  550.0  266.0
# orion_cnrgtuax_0      NaN  NaN  365.0  1122.0  799.0      NaN  415.0  257.0
# orion_cqxbwsky_0      NaN  NaN  641.0  3067.0  923.0      NaN  745.0  330.0
#
#                    CD8a  CD45RO   CD20  PD-L1    CD3e  CD163  E-cadherin  \
# orion_aijcgfvk_0  279.0  1116.0  275.0  565.0   560.0  972.0      2214.0
# orion_aisfibhi_0  278.0   611.0  270.0  547.0   607.0  678.0      1086.0
# orion_bzoahikx_0  726.0  1113.0  496.0  968.0  1167.0  886.0       914.0
# orion_cnrgtuax_0  335.0   752.0  350.0  649.0   567.0  487.0      1393.0
# orion_cqxbwsky_0  386.0   748.0  474.0  624.0  1193.0  939.0      2979.0
#
#                    PD-1    Ki67  Pan-CK    SMA
# orion_aijcgfvk_0  436.0  2733.0  1602.0  622.0
# orion_aisfibhi_0  437.0   874.0  2629.0  806.0
# orion_bzoahikx_0  470.0   569.0  2180.0  628.0
# orion_cnrgtuax_0  313.0   562.0  1899.0  905.0
# orion_cqxbwsky_0  593.0  1430.0  2298.0  912.0
# 2025-12-17 21:16:48.055 | ERROR    | src.dataset.datasets.mm_base:__init__:55 - An error has been caught in function '__init__', process 'MainProcess' (5806), thread 'MainThread' (137572154341184):
# Traceback (most recent call last):
#
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/opt/conda/envs/tissuevit/lib/python3.12/site-packages/ipykernel/kernelapp.py'>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7d1f00a76980>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7d1f01cc9e20>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x7d1f00aa9440>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7d1edf489730>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7d1f01cc9e20>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x7d1f0242ccc0>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7d1edf489730>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x7d1f0242eac0>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7d1f023caf20>
#     └ <Handle <_asyncio.TaskStepMethWrapper object at 0x7d1cb43e8220>()>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle <_asyncio.TaskStepMethWrapper object at 0x7d1cb43e8220>()>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle <_asyncio.TaskStepMethWrapper object at 0x7d1cb43e8220>()>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle <_asyncio.TaskStepMethWrapper object at 0x7d1cb43e8220>()>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#           │    │              │                └ None
#           │    │              └ [<zmq.Frame(b'958771b8-b23'...36B)>, <zmq.Frame(b'<IDS|MSG>')>, <zmq.Frame(b'cc5ed6e55d39'...64B)>, <zmq.Frame(b'{"date":"202...
#           │    └ <function Kernel.dispatch_shell at 0x7d1f00c14720>
#           └ <ipykernel.ipkernel.IPythonKernel object at 0x7d1f00a90b90>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_shell
#     await result
#           └ <coroutine object IPythonKernel.execute_request at 0x7d1cb296fd30>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#                                   │       │      └ {'header': {'date': datetime.datetime(2025, 12, 17, 21, 16, 47, 971000, tzinfo=tzutc()), 'msg_id': 'a2c968f0-fd7c-4fbb-824c-1...
#                                   │       └ [b'958771b8-b233-41c5-a9c4-03df19236e2f']
#                                   └ <zmq.Socket(zmq.PAIR) at 0x7d1edf4ba900>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#                           └ <coroutine object IPythonKernel.do_execute at 0x7d1cb27c73d0>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#           │     └ <function ZMQInteractiveShell.run_cell at 0x7d1f00c50e00>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7d1f00ab0890>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#                              │       └ {'store_history': True, 'silent': False, 'cell_id': 'vscode-notebook-cell://tunnel%2Bjon-gpu/data/code/jon/project-2-gradient...
#                              └ ('set_seed(SEED)\n\n# ----------------------------\n# Build dataset configs exactly like you do\n# --------------------------...
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x7d1f015c4040>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7d1f00ab0890>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#              │      └ <coroutine object InteractiveShell.run_cell_async at 0x7d1cb352a5a0>
#              └ <function _pseudo_sync_runner at 0x7d1f0159efc0>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x7d1cb352a5a0>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '/tmp/ipykernel_5806/263910482.py'
#                        │    │             │        └ [<ast.Expr object at 0x7d1cb214a390>, <ast.Assign object at 0x7d1cb2149710>, <ast.Assign object at 0x7d1cb2149e10>, <ast.Assi...
#                        │    │             └ <ast.Module object at 0x7d1cb2148e10>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x7d1f015c4400>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7d1f00ab0890>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#              │    │        │     │              └ False
#              │    │        │     └ <ExecutionResult object at 7d1cb2702ed0, execution_count=10 error_before_exec=None error_in_exec=None info=<ExecutionInfo obj...
#              │    │        └ <code object <module> at 0x7d1cb2b03ad0, file "/tmp/ipykernel_5806/263910482.py", line 1>
#              │    └ <function InteractiveShell.run_code at 0x7d1f015c44a0>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7d1f00ab0890>
#   File "/opt/conda/envs/tissuevit/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ <property object at 0x7d1f015b4770>
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7d1f00ab0890>
#          │         │    └ <property object at 0x7d1f015b4810>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7d1f00ab0890>
#          └ <code object <module> at 0x7d1cb2b03ad0, file "/tmp/ipykernel_5806/263910482.py", line 1>
#
#   File "/tmp/ipykernel_5806/263910482.py", line 10, in <module>
#     ds = build_mm_datasets(ds_cfg)
#          │                 └ {'dataset_config': None, 'additional_config': None, 'marker_embedding_dir': '/datasets/marker_embeddings/esm2_t30_150M_UR50D'...
#          └ <function build_mm_datasets at 0x7d1e2ef6a0c0>
#
#   File "/data/code/jon/project-2-gradient_tri_scent/src/dataset/datasets/mm_base.py", line 17, in build_mm_datasets
#     mm_dataset = build_mm_dataset(conf, ds_conf, **kwargs)
#                  │                │     │          └ {}
#                  │                │     └ {'name': 'orion', 'path': '/data/virtues_orion_dataset/virtues_example/orion_subset', 'modalities': ['cycif', 'he'], 'load_ma...
#                  │                └ {'dataset_config': None, 'additional_config': None, 'marker_embedding_dir': '/datasets/marker_embeddings/esm2_t30_150M_UR50D'...
#                  └ <function build_mm_dataset at 0x7d1cb4c56200>
#
#   File "/data/code/jon/project-2-gradient_tri_scent/src/dataset/datasets/mm_base.py", line 28, in build_mm_dataset
#     dataset = MultimodalDataset(name=ds_conf.name, path=ds_conf.path, modalities=ds_conf.modalities, rnd_crop_size=conf.image_info.rnd_crop_size, normalization=conf.image_info.normalization,
#               │                      │                  │                        │                                 │                                            └ {'dataset_config': None, 'additional_config': None, 'marker_embedding_dir': '/datasets/marker_embeddings/esm2_t30_150M_UR50D'...
#               │                      │                  │                        │                                 └ {'dataset_config': None, 'additional_config': None, 'marker_embedding_dir': '/datasets/marker_embeddings/esm2_t30_150M_UR50D'...
#               │                      │                  │                        └ {'name': 'orion', 'path': '/data/virtues_orion_dataset/virtues_example/orion_subset', 'modalities': ['cycif', 'he'], 'load_ma...
#               │                      │                  └ {'name': 'orion', 'path': '/data/virtues_orion_dataset/virtues_example/orion_subset', 'modalities': ['cycif', 'he'], 'load_ma...
#               │                      └ {'name': 'orion', 'path': '/data/virtues_orion_dataset/virtues_example/orion_subset', 'modalities': ['cycif', 'he'], 'load_ma...
#               └ <class 'src.dataset.datasets.mm_base.MultimodalDataset'>
#
# > File "/data/code/jon/project-2-gradient_tri_scent/src/dataset/datasets/mm_base.py", line 55, in __init__
#     self.unimodal_datasets[modality] = MultiplexDataset(name, path, modality, rnd_crop_size, normalization, embedding_dir, crop_strategy, removed_channel_names=removed_channel_names, custom_gene_dict=custom_gene_dict, **kwargs)
#     │    │                 │           │                │     │     │         │              │              │              │                                    │                                       │                   └ {}
#     │    │                 │           │                │     │     │         │              │              │              │                                    │                                       └ None
#     │    │                 │           │                │     │     │         │              │              │              │                                    └ None
#     │    │                 │           │                │     │     │         │              │              │              └ 'random_crops'
#     │    │                 │           │                │     │     │         │              │              └ '/datasets/marker_embeddings/esm2_t30_150M_UR50D'
#     │    │                 │           │                │     │     │         │              └ 'q_99'
#     │    │                 │           │                │     │     │         └ 256
#     │    │                 │           │                │     │     └ 'cycif'
#     │    │                 │           │                │     └ '/data/virtues_orion_dataset/virtues_example/orion_subset'
#     │    │                 │           │                └ 'orion'
#     │    │                 │           └ <class 'src.dataset.datasets.multiplex_base.MultiplexDataset'>
#     │    │                 └ 'cycif'
#     │    └ {}
#     └ <src.dataset.datasets.mm_base.MultimodalDataset object at 0x7d1cb1f50e00>
#
#   File "/data/code/jon/project-2-gradient_tri_scent/src/dataset/datasets/multiplex_base.py", line 145, in __init__
#     self.uniprot_to_index = load_marker_embedding_dict(embedding_dir=embedding_dir)
#     │                       │                                        └ '/datasets/marker_embeddings/esm2_t30_150M_UR50D'
#     │                       └ <function load_marker_embedding_dict at 0x7d1cb4c56340>
#     └ <src.dataset.datasets.multiplex_base.MultiplexDataset object at 0x7d1cb1f51a00>
#
#   File "/data/code/jon/project-2-gradient_tri_scent/src/utils/marker_utils.py", line 9, in load_marker_embedding_dict
#     raise ValueError(f"Could not find embedding_dir {embedding_dir}")
#                                                      └ '/datasets/marker_embeddings/esm2_t30_150M_UR50D'
#
# ValueError: Could not find embedding_dir /datasets/marker_embeddings/esm2_t30_150M_UR50D
# 2025-12-17 21:16:48.062 | INFO     | src.dataset.datasets.he_base:__init__:26 - H&E Normalization metadata: BaseHENormalizeMetadata(rnd_crop_folder_name='random_crops_256')
# Total tissues: 35
#
# Sanity checks:
# Fold1 sizes: 28 7 overlap: 0
# Fold2 sizes: 28 7 overlap: 0
# Fold1 test ∩ Fold2 test: 0
#
# Saved folds to: /data/code/jon/project-2-gradient_tri_scent/notebooks/checkpoints/two_folds_seed42_tissue_split.pkl
